# %%
import re
from bs4 import BeautifulSoup
import requests
import html5lib
import json

# %%
url = 'https://www.cna.com.tw/list/aspt.aspx'
res = requests.get(url)
soup = BeautifulSoup(res.text,'html5lib')
n=0
labels=[]
while n < len(soup.select_one('#pnProductNavContents > ul').findAll('li')):
    try :
        lab = soup.select_one('#pnProductNavContents > ul').findAll('li')[n].find('a',{'class':'first-level'}).text
        url =soup.select_one('#pnProductNavContents > ul').findAll('li')[n].find('a',{'class':'first-level'})['href']
    except:(TypeError,IndentationError)
    labels.append((url,lab))
    n += 1
labels = list(set(labels))
labels.remove(('http://cnavideo.cna.com.tw', '影音'))
labels.remove(('/list/aall.aspx', '即時'))
labels.append(('https://www.cna.com.tw/list/aall.aspx', '即時'))
#labels.remove(('https://www.cna.com.tw/keyword/九合一.aspx', '九合一'))
labels.remove(('https://www.cna.com.tw/list/sp.aspx', '專題'))
labels.remove(('https://www.cna.com.tw/list/aall.aspx', '即時'))

labs = []
for item in labels:
    item = [item[0],item[1]]

    item[0] = re.search(r'list\/\w+',item[0]).group()[5:]
    labs.append(item)

# %%
def payload(item):
    payload={
        'id': '1056893641102242',
    'ev': 'Microdata',
    'dl': item[0],
    'rl': 'https://www.cna.com.tw/',
    'if': 'false',
    'ts': '1541087113735',
    'cd[Schema.org]': [],
    #'cd[OpenGraph]': {"og:url":"https://www.cna.com.tw/list/ahel.aspx","og:title":"生活 | 中央社 CNA","og:description":"想知道統一發票、大樂透、威力彩開獎號碼、各種醫療保健、交通氣象、颱風動態等生活資訊，及升學考試、教育政策、課綱改革等文教訊息，通通都在中央社生活新聞。","og:image:height":"200","og:image:width":"200","og:image":"https://img5.cna.com.tw/www/images/pic_fb.jpg","og:type":"article","article:author":"https://www.facebook.com/cnanewstaiwan","article:publisher":"https://www.facebook.com/cnanewstaiwan"}
    #'cd[Meta]': {"title":"\n\t生活 | 中央社 CNA\n","meta:description":"想知道統一發票、大樂透、威力彩開獎號碼、各種醫療保健、交通氣象、颱風動態等生活資訊，及升學考試、教育政策、課綱改革等文教訊息，通通都在中央社生活新聞。","meta:keywords":"News, 新聞, 即時新聞, 中央社"}
    'cd[DataLayer]': [],
    'cd[JSON-LD]': [],
    'sw': '1280',
    'sh': '5000',#'720',
    'v': '2.8.30',
    'r': 'stable',
    'a': 'tmgoogletagmanager',
    'ec': '1',
    'o': '30',
    'fbp': 'fb.2.1541074934894.620990608',
    'it': '1541087112886',
    'coo': 'false',
    'es': 'automatic',
    }
    return payload

# %%
labs_soup=[]
for item in labs:
    soups=[]
    n=1
    while n < 13:
        url = 'https://www.cna.com.tw/cna2018api/api/simplelist/categorycode/'+item[0]+'/pageidx/'+str(n)
        res = requests.get(url)
        soup = BeautifulSoup(res.text,'html5lib')
        body = soup.findAll('body')[0].getText()
        PageUrl = re.findall(r'\"PageUrl\"\:\S[^\,]+',body)
        urls = [txt[11:-1] for txt in PageUrl]
        soups.extend(urls)
        n += 1
        if len(urls) < 20:
            break
    labs_soup.append([soups,item[1]])

# %%
news={}
for lab in labs_soup:
    lab_name = lab[1]
    lab_urls = lab[0]
    n = 0
    for url in lab_urls:
        res = requests.get(url)
        soup = BeautifulSoup(res.text,'html5lib')
        txt = ""
        try:
            for s in soup.find_all('div',{'class':'paragraph'})[0].findAll('p'):
                txt=txt+s.getText()
        except:IndexError
            
        research = re.search(r'[\）\)\：\:\》](.+[\。\!\?\s])+',txt)
        if research == None or len(research.group())<2:
#        if re.search(r'',txt) == None:
            print(txt)
        else:
            txt = re.search(r'[\）\)\：\:\》](.+[\。\!\?\s])+',txt).group()[1:]


        news[txt]=lab_name
        n += 1
        if n % 20 == 0:
            print((lab_name,n),end=",")
# Out:
# ('兩岸', 20),中央社駐香港特派員張謙/12月3日4年前「占中運動」爆發時，香港泛民主派一度氣勢如虹，並於2016年底的立法會選舉取得不錯成績，但近年來形勢逆轉，泛民面對不少內憂壓力。挾著年輕力量的崛起，泛民於2016年9月的立法會選舉大有斬獲，共取得26席。當中包括一人一票的分區直選議席，以及以業界區分的功能組別議席。功能組別以業界人士或代表區分，從來都是泛民較弱的版塊，但當年泛民在這方面獲得的選票大增，顯示其勢力正往業界延伸，威脅親政府建制派的基本盤。但「占中」之後，當局在北京中央高喊必須對「港獨」零容忍的情況下，開始以行政手段限制立場較為偏激的泛民人士參選。主要要求各候選人在參選前，必須簽署一份參選聲明，表明自己擁護基本法和保證效忠香港特別行政區。這項新規定導致一些泛民代表、特別是主張「港獨」的年輕代表，無法參加當年的立法會選舉，甚至讓新成立的年輕政黨香港眾志，一夜之間被排除在選舉之外，無法透過參選而進入香港管治架構。選後，當局也對泛民當選者窮追猛打，以他們在宣誓就任時未符合基本法所規定的「莊嚴」要求，向法院提出聲請，要求褫奪他們的資格，結果導致泛民6人喪失議席。進入2018年，泛民的困境並未消除。在立法會議員補選中未能拿回失去的全部議席，僅取回3席，失去另外2席，讓泛民在議會的人數減少。今年3月和11月，當局為泛民失去的其中5個議席進行補選，其中3月補選4人，11月補選1人。結果泛民在3月只贏回兩席，失去另外2席。更重要的是，泛民在一人一票的地方直選，被建制派打敗而失去1席，這是泛民和建制派歷來在一對一的對決下，首次落敗。在上月的補選中，泛民同樣在地方直選中落敗，受挫的的更是泛民元老級人馬、工黨成員李卓人。對於泛民連續兩次在一人一票地方直選、一對一對決之下敗給建制派，有學者解讀為泛民和建制的政治版圖正在發生變化。香港輿論和媒體一向認為，自香港主權轉移以來，泛民和建制無論在立法會或區議會的選舉，得票總和多是6比4，即前者得6成票，後者4成票。所以，每逢直選選區只有泛民和建制對決，建制派必定落敗，這種現象的背後，反映出兩派的民意基礎和支持度有差距。對於泛民連續兩次在直選落敗，香港中文大學政治與行政學系高級講師蔡子強說，這已非偶然事件，可能反映出政治版圖正在變化，即泛民和建制力量的對比有所轉變。至於轉變的原因有多方面，主因是泛民的多名年輕代表被褫奪立法會議席或參選資格後，讓年輕人對政治冷感，以致泛民流失票源。前立法會議員黃成智受訪時認為，泛民和建制的得票黃金比率沒有變，選民也沒有變，泛民這次落敗是內部團結出現問題，比如傳統派系和新崛起本土派的矛盾，以致票源生變。從泛民和建制派在兩次補選的得票率看，建制派得票率基本上沒有大增，只能說維持基本盤，但泛民的得票出現流失，這確有可能是泛民內部出了問題。因此，泛民若能找到問題所在，包括外界所指的內部團結問題，以及失去溫和中產階層的支持，也許可以走出當前困局。（編輯：林克倫）1071203
# ('兩岸', 40),('兩岸', 60),('兩岸', 80),('兩岸', 100),('文化', 20),('文化', 40),('文化', 60),('文化', 80),('文化', 100),('產經', 20),('產經', 40),('產經', 60),('產經', 80),('產經', 100),('國際', 20),('國際', 40),('國際', 60),('國際', 80),('國際', 100),('科技', 20),('科技', 40),('科技', 60),('科技', 80),('科技', 100),('地方', 20),('地方', 40),('地方', 60),('地方', 80),('地方', 100),('政治', 20),('政治', 40),('政治', 60),('政治', 80),('政治', 100),('生活', 20),('生活', 40),('生活', 60),('生活', 80),('生活', 100),('社會', 20),('社會', 40),('社會', 60),('社會', 80),('社會', 100),('運動', 20),('運動', 40),('運動', 60),('運動', 80),('運動', 100),('證券', 20),('證券', 40),('證券', 60),('證券', 80),('證券', 100),('娛樂', 20),('娛樂', 40),('娛樂', 60),('娛樂', 80),('娛樂', 100),

# %%
import jieba
import nltk

# %%
stopwords=[]
with open('../30/txt/stopwords_ch.txt', 'r', encoding='UTF-8') as file:
    for data in file.readlines():
        data = data.strip()
        stopwords.append(data)

# %%
lab_tags ={}
prelab = ''
books = list(news.items())
for book in books:
    for lab in ['生活','運動','政治','科技','國際','兩岸','產經','社會','地方','娛樂','證券','文化']:
        if book[1]==lab:
            if prelab != lab:
                txt=''
            txt = txt+book[0]
            lab_tags[book[1]] = txt
            prelab = lab

# %%
filterwords=[
    '年','月','中央社','記者','編輯','譯者','日電',
    '\n',' ','「','」'
    ,'今天','說','表示','年','月','日','後','前','時','應','中','今年'
    ,'兩','下','人','最','次','再','先'
]

# %%
def get_fwords():
    lab_fwords={}
    lab_Ftwowords = {}
    for labname in lab_tags.keys():
        print(labname,end=',')
        lab_words = lab_tags[labname]
    #    seg_list = jieba.cut_for_search(lab_words)#, cut_all=False)
        seg_list = jieba.cut(lab_words, cut_all=False)
        txt = ",".join(seg_list)
        tokens = txt.split(',')
        tokens = list(filter(lambda a: a not in stopwords and a not in filterwords and a.isalpha() == True,tokens))#and len(a)>1, tokens))
        ###
        lab_alltwowords = list(nltk.bigrams(tokens))
        two = nltk.FreqDist(lab_alltwowords).most_common(500)
        lab_Ftwowords[labname] = [(i[0]+i[1],j) for i,j in two]
        ###
        lab_fwords[labname] =  [i for i in nltk.FreqDist(tokens).most_common(500)]
    return lab_fwords,lab_Ftwowords

# %%
lab_fwords,lab_Ftwowords = get_fwords()
# Out:
# 兩岸,文化,產經,國際,科技,地方,政治,生活,社會,運動,證券,娛樂,

# %%
#去除交集的高頻字

dic3={}
for lab in lab_fwords.keys():   
    word_content2 = lab_fwords[lab].copy()
    for lab2 in lab_fwords.keys():        
        if lab != lab2:
            word_content = [w for w in lab_fwords[lab] if (w[0] in [a[0] for a in lab_fwords[lab2]]) ][:15]
            for w in word_content:
                try:
                    word_content2.remove(w)                  
                except ValueError:
                    pass
    dic3[lab] = word_content2  
    
    
    
dic2={}
for lab in lab_Ftwowords.keys():   
    word_content2 = lab_Ftwowords[lab].copy()
    for lab2 in lab_Ftwowords.keys():        
        if lab != lab2:
            word_content = [w for w in lab_Ftwowords[lab] if (w[0] in [a[0] for a in lab_Ftwowords[lab2]]) ][:15]
            for w in word_content:
                try:
                    word_content2.remove(w)                   
                except ValueError:
                    pass
    dic2[lab] = word_content2
    
lab_Ftwowords = dic2
lab_fwords = dic3

# %%
lab_fwords['兩岸'][:]
# Out:
# [('中共', 49),
#  ('進口', 49),
#  ('新疆', 48),
#  ('中美', 47),
#  ('代表', 46),
#  ('工作', 46),
#  ('政策', 45),
#  ('論壇', 43),
#  ('上海', 42),
#  ('當局', 40),
#  ('交流', 38),
#  ('人民幣', 38),
#  ('就業', 38),
#  ('國際', 37),
#  ('憲法', 37),
#  ('進行', 36),
#  ('市場', 36),
#  ('新聞', 36),
#  ('占', 36),
#  ('提出', 35),
#  ('人士', 34),
#  ('些', 34),
#  ('泛民', 34),
#  ('舉行', 33),
#  ('種', 33),
#  ('政治', 33),
#  ('大學', 33),
#  ('官方', 33),
#  ('支持', 33),
#  ('項', 32),
#  ('改革', 32),
#  ('方面', 32),
#  ('文化', 31),
#  ('措施', 31),
#  ('官員', 31),
#  ('人員', 31),
#  ('曾', 31),
#  ('學生', 31),
#  ('開放', 30),
#  ('委員會', 30),
#  ('目前', 30),
#  ('出現', 30),
#  ('活動', 30),
#  ('指', 30),
#  ('電台', 29),
#  ('民眾', 29),
#  ('陳', 29),
#  ('影響', 29),
#  ('習近平', 28),
#  ('疫情', 28),
#  ('選舉', 28),
#  ('資料', 27),
#  ('數據', 27),
#  ('持續', 26),
#  ('情況', 26),
#  ('首', 26),
#  ('地方', 26),
#  ('雙方', 25),
#  ('遭', 25),
#  ('以來', 25),
#  ('成為', 25),
#  ('中央', 25),
#  ('地區', 25),
#  ('雙城', 25),
#  ('主任', 25),
#  ('指數', 25),
#  ('內容', 24),
#  ('希望', 24),
#  ('舉辦', 24),
#  ('部', 24),
#  ('處理', 24),
#  ('禁止', 24),
#  ('申請', 24),
#  ('全國', 24),
#  ('媒體', 24),
#  ('部門', 24),
#  ('顯示', 24),
#  ('公司', 24),
#  ('學者', 23),
#  ('共同', 23),
#  ('加強', 23),
#  ('積極', 23),
#  ('中心', 23),
#  ('陸委會', 23),
#  ('調查', 23),
#  ('組織', 23),
#  ('重要', 23),
#  ('汙染', 23),
#  ('中方', 22),
#  ('共識', 22),
#  ('主要', 22),
#  ('報告', 22),
#  ('強調', 22),
#  ('平台', 22),
#  ('城市', 22),
#  ('昨天', 22),
#  ('透過', 22),
#  ('律師', 22),
#  ('環境', 22),
#  ('幹部', 22),
#  ('管理', 22),
#  ('阿里', 22),
#  ('短', 22),
#  ('台', 21),
#  ('資訊', 21),
#  ('發布', 21),
#  ('分', 21),
#  ('實施', 21),
#  ('台北', 21),
#  ('發表', 20),
#  ('穩定', 20),
#  ('產業', 20),
#  ('出席', 20),
#  ('引述', 20),
#  ('立法會', 20),
#  ('億', 20),
#  ('壓力', 20),
#  ('汽車', 20),
#  ('符合', 19),
#  ('取得', 19),
#  ('進一步', 19),
#  ('金融', 19),
#  ('縣', 19),
#  ('會議', 19),
#  ('規定', 19),
#  ('嚴重', 19),
#  ('只', 19),
#  ('獲得', 19),
#  ('研究', 19),
#  ('事故', 19),
#  ('鐵路', 19),
#  ('峰會', 18),
#  ('提供', 18),
#  ('公布', 18),
#  ('頭', 18),
#  ('正', 18),
#  ('未', 18),
#  ('當時', 18),
#  ('安全', 18),
#  ('法律', 18),
#  ('自由', 18),
#  ('文章', 18),
#  ('原則', 18),
#  ('確定', 18),
#  ('份', 18),
#  ('李', 18),
#  ('網民', 18),
#  ('食品', 18),
#  ('聲明', 17),
#  ('繼續', 17),
#  ('貿易', 17),
#  ('條', 17),
#  ('限制', 17),
#  ('當地', 17),
#  ('上述', 17),
#  ('受', 17),
#  ('歲', 17),
#  ('過程', 17),
#  ('日前', 17),
#  ('協會', 17),
#  ('過去', 17),
#  ('約', 17),
#  ('失業', 17),
#  ('家', 17),
#  ('警方', 17),
#  ('上海市', 17),
#  ('發言人', 17),
#  ('網路', 17),
#  ('專家', 17),
#  ('主席', 16),
#  ('會晤', 16),
#  ('川', 16),
#  ('習會', 16),
#  ('溝通', 16),
#  ('技術', 16),
#  ('服務', 16),
#  ('宣布', 16),
#  ('劉', 16),
#  ('單位', 16),
#  ('發現', 16),
#  ('居住證', 16),
#  ('造成', 16),
#  ('國務院', 16),
#  ('已經', 16),
#  ('領導', 16),
#  ('好', 16),
#  ('萬', 16),
#  ('來台', 16),
#  ('節目', 16),
#  ('基本法', 16),
#  ('關稅', 16),
#  ('貿易戰', 15),
#  ('當前', 15),
#  ('川普', 15),
#  ('存在', 15),
#  ('世界', 15),
#  ('推動', 15),
#  ('因素', 15),
#  ('綜合', 15),
#  ('青年', 15),
#  ('銀行', 15),
#  ('運動', 15),
#  ('農村', 15),
#  ('生豬', 15),
#  ('機制', 15),
#  ('外', 15),
#  ('亞洲', 15),
#  ('接受', 15),
#  ('報章', 15),
#  ('記者會', 15),
#  ('消息', 15),
#  ('新華社', 15),
#  ('視頻', 15),
#  ('匯率', 15),
#  ('參選', 15),
#  ('溫泉', 15),
#  ('感染', 15),
#  ('美方', 14),
#  ('落實', 14),
#  ('談判', 14),
#  ('企業家', 14),
#  ('討論', 14),
#  ('成立', 14),
#  ('投資', 14),
#  ('旅遊', 14),
#  ('農業', 14),
#  ('非洲', 14),
#  ('辦公室', 14),
#  ('卻', 14),
#  ('通報', 14),
#  ('宣誓', 14),
#  ('近日', 14),
#  ('邀請', 14),
#  ('正在', 14),
#  ('事件', 14),
#  ('是否', 14),
#  ('全面', 14),
#  ('這是', 14),
#  ('立場', 14),
#  ('產能', 14),
#  ('超過', 14),
#  ('扶貧', 14),
#  ('事務', 14),
#  ('去年', 14),
#  ('監測', 14),
#  ('總局', 14),
#  ('基礎', 14),
#  ('退出', 14),
#  ('空氣', 14),
#  ('決定', 14),
#  ('造紙', 14),
#  ('時間', 13),
#  ('特別', 13),
#  ('解決', 13),
#  ('形勢', 13),
#  ('期間', 13),
#  ('重視', 13),
#  ('機構', 13),
#  ('教育', 13),
#  ('交易', 13),
#  ('稱', 13),
#  ('豬瘟', 13),
#  ('區', 13),
#  ('處置', 13),
#  ('規模', 13),
#  ('需要', 13),
#  ('海外', 13),
#  ('外界', 13),
#  ('非', 13),
#  ('行為', 13),
#  ('完成', 13),
#  ('各地', 13),
#  ('和平', 13),
#  ('日起', 13),
#  ('議員', 13),
#  ('預計', 13),
#  ('汪洋', 13),
#  ('堅持', 13),
#  ('工作室', 13),
#  ('內部', 13),
#  ('區域', 13),
#  ('減稅', 13),
#  ('朱', 13),
#  ('影音', 13),
#  ('達成', 12),
#  ('與會', 12),
#  ('經貿', 12),
#  ('健康', 12),
#  ('兩國', 12),
#  ('智慧', 12),
#  ('天', 12),
#  ('關注', 12),
#  ('能源', 12),
#  ('創業', 12),
#  ('科技', 12),
#  ('範圍', 12),
#  ('無法', 12),
#  ('北京市', 12),
#  ('方案', 12),
#  ('人權', 12),
#  ('保障', 12),
#  ('國台辦', 12),
#  ('意見', 12),
#  ('高', 12),
#  ('許多', 12),
#  ('一些', 12),
#  ('作', 12),
#  ('左右', 12),
#  ('評論', 12),
#  ('生活', 12),
#  ('批', 12),
#  ('一直', 12),
#  ('進入', 12),
#  ('鼓勵', 12),
#  ('連續', 12),
#  ('宗教', 12),
#  ('以上', 12),
#  ('研討會', 12),
#  ('標準', 12),
#  ('萬人', 12),
#  ('行業', 12),
#  ('近期', 12),
#  ('柯文哲', 12),
#  ('探視', 12),
#  ('領袖', 11),
#  ('美', 11),
#  ('場', 11),
#  ('總統', 11),
#  ('阿根廷', 11),
#  ('廈門市', 11),
#  ('陸方', 11),
#  ('協助', 11),
#  ('困難', 11),
#  ('啟動', 11),
#  ('採取', 11),
#  ('至今', 11),
#  ('條件', 11),
#  ('做', 11),
#  ('國內', 11),
#  ('通知', 11),
#  ('日報', 11),
#  ('參加', 11),
#  ('參與', 11),
#  ('針對', 11),
#  ('台辦', 11),
#  ('中華民國', 11),
#  ('年底', 11),
#  ('名單', 11),
#  ('行動', 11),
#  ('公眾', 11),
#  ('妨擾', 11),
#  ('全球', 11),
#  ('治理', 11),
#  ('寧夏', 11),
#  ('民族', 11),
#  ('無', 11),
#  ('保持', 11),
#  ('稅務', 11),
#  ('輛', 11),
#  ('導致', 11),
#  ('展開', 11),
#  ('團體', 11),
#  ('集團', 11),
#  ('空間', 11),
#  ('變', 11),
#  ('九二', 11),
#  ('美元', 11),
#  ('降低', 11),
#  ('預警', 11),
#  ('委書記', 11),
#  ('明年', 11),
#  ('雄安', 11),
#  ('洞庭湖', 11),
#  ('PMI', 11),
#  ('選手', 11),
#  ('藏', 11),
#  ('智庫', 10),
#  ('提到', 10),
#  ('環保', 10),
#  ('促進', 10),
#  ('放寬', 10),
#  ('議題', 10),
#  ('經驗', 10),
#  ('增加', 10),
#  ('死亡', 10),
#  ('所有', 10),
#  ('機場', 10),
#  ('有效', 10),
#  ('泰國', 10),
#  ('規範', 10),
#  ('部分', 10),
#  ('發出', 10),
#  ('機會', 10),
#  ('出口', 10),
#  ('展館', 10),
#  ('使用', 10),
#  ('全', 10),
#  ('變化', 10),
#  ('風險', 10),
#  ('讀取', 10),
#  ('RFID', 10),
#  ('殭屍', 10),
#  ('經營', 10),
#  ('生產', 10),
#  ('開展', 10),
#  ('計畫', 10),
#  ('引發', 10),
#  ('煽惑', 10),
#  ('歷史', 10),
#  ('了解', 10),
#  ('陸媒', 10),
#  ('手段', 10),
#  ('職工', 10),
#  ('李克強', 10),
#  ('萬元', 10),
#  ('補稅', 10),
#  ('吳京', 10),
#  ('統一', 10),
#  ('主權', 10),
#  ('台商', 10),
#  ('主義', 10),
#  ('下滑', 10),
#  ('天津', 10),
#  ('河北', 10),
#  ('公開', 10),
#  ('負責人', 10),
#  ('黨報', 10),
#  ('公告', 10),
#  ('法規', 10),
#  ('美食', 10),
#  ('廣播', 10),
#  ('商品', 10),
#  ('之音', 10),
#  ('網絡', 10),
#  ('例行', 10),
#  ('醫藥', 10),
#  ('環聯', 10),
#  ('塗鴉', 10),
#  ('建議', 9),
#  ('一致', 9),
#  ('協議', 9),
#  ('保護', 9),
#  ('化', 9),
#  ('補貼', 9),
#  ('努力', 9),
#  ('成果', 9),
#  ('涉及', 9),
#  ('總體', 9),
#  ('未能', 9),
#  ('狀況', 9),
#  ('晚間', 9),
#  ('機關', 9),
#  ('訊息', 9),
#  ('回應', 9),
#  ('法制', 9),
#  ('擔任', 9),
#  ('程序', 9),
#  ('所謂', 9),
#  ('副主任', 9),
#  ('採訪', 9),
#  ('調整', 9),
#  ('隨後', 9),
#  ('故事', 9),
#  ('建立', 9),
#  ('成功', 9),
#  ('處於', 9),
#  ('優勢', 9),
#  ('電子', 9),
#  ('維持', 9),
#  ('達', 9),
#  ('安排', 9),
#  ('陳健民', 9)]

# %%
[i for i in lab_fwords['兩岸'] if i[0] in [w[0] for w in lab_fwords['國際']]]
# Out:
# [('進口', 49),
#  ('中美', 47),
#  ('代表', 46),
#  ('工作', 46),
#  ('政策', 45),
#  ('論壇', 43),
#  ('當局', 40),
#  ('新聞', 36),
#  ('提出', 35),
#  ('人士', 34),
#  ('些', 34),
#  ('舉行', 33),
#  ('種', 33),
#  ('政治', 33),
#  ('官方', 33),
#  ('支持', 33),
#  ('改革', 32),
#  ('方面', 32),
#  ('文化', 31),
#  ('措施', 31),
#  ('官員', 31),
#  ('人員', 31),
#  ('曾', 31),
#  ('委員會', 30),
#  ('目前', 30),
#  ('出現', 30),
#  ('活動', 30),
#  ('民眾', 29),
#  ('影響', 29),
#  ('習近平', 28),
#  ('選舉', 28),
#  ('持續', 26),
#  ('情況', 26),
#  ('首', 26),
#  ('地方', 26),
#  ('雙方', 25),
#  ('遭', 25),
#  ('以來', 25),
#  ('成為', 25),
#  ('地區', 25),
#  ('希望', 24),
#  ('部', 24),
#  ('處理', 24),
#  ('禁止', 24),
#  ('顯示', 24),
#  ('加強', 23),
#  ('中心', 23),
#  ('調查', 23),
#  ('組織', 23),
#  ('重要', 23),
#  ('中方', 22),
#  ('共識', 22),
#  ('主要', 22),
#  ('報告', 22),
#  ('城市', 22),
#  ('昨天', 22),
#  ('透過', 22),
#  ('發布', 21),
#  ('分', 21),
#  ('台北', 21),
#  ('發表', 20),
#  ('出席', 20),
#  ('引述', 20),
#  ('億', 20),
#  ('汽車', 20),
#  ('取得', 19),
#  ('會議', 19),
#  ('規定', 19),
#  ('嚴重', 19),
#  ('獲得', 19),
#  ('公布', 18),
#  ('正', 18),
#  ('未', 18),
#  ('當時', 18),
#  ('安全', 18),
#  ('法律', 18),
#  ('自由', 18),
#  ('份', 18),
#  ('聲明', 17),
#  ('繼續', 17),
#  ('貿易', 17),
#  ('限制', 17),
#  ('當地', 17),
#  ('上述', 17),
#  ('歲', 17),
#  ('過去', 17),
#  ('約', 17),
#  ('家', 17),
#  ('警方', 17),
#  ('發言人', 17),
#  ('網路', 17),
#  ('主席', 16),
#  ('會晤', 16),
#  ('習會', 16),
#  ('技術', 16),
#  ('服務', 16),
#  ('宣布', 16),
#  ('造成', 16),
#  ('國務院', 16),
#  ('已經', 16),
#  ('領導', 16),
#  ('萬', 16),
#  ('關稅', 16),
#  ('貿易戰', 15),
#  ('世界', 15),
#  ('青年', 15),
#  ('外', 15),
#  ('接受', 15),
#  ('記者會', 15),
#  ('消息', 15),
#  ('美方', 14),
#  ('談判', 14),
#  ('討論', 14),
#  ('投資', 14),
#  ('辦公室', 14),
#  ('卻', 14),
#  ('正在', 14),
#  ('事件', 14),
#  ('是否', 14),
#  ('這是', 14),
#  ('立場', 14),
#  ('超過', 14),
#  ('去年', 14),
#  ('退出', 14),
#  ('決定', 14),
#  ('時間', 13),
#  ('特別', 13),
#  ('解決', 13),
#  ('期間', 13),
#  ('機構', 13),
#  ('需要', 13),
#  ('外界', 13),
#  ('非', 13),
#  ('行為', 13),
#  ('和平', 13),
#  ('議員', 13),
#  ('達成', 12),
#  ('兩國', 12),
#  ('天', 12),
#  ('無法', 12),
#  ('方案', 12),
#  ('人權', 12),
#  ('高', 12),
#  ('許多', 12),
#  ('一直', 12),
#  ('進入', 12),
#  ('宗教', 12),
#  ('萬人', 12),
#  ('美', 11),
#  ('場', 11),
#  ('協助', 11),
#  ('採取', 11),
#  ('做', 11),
#  ('參加', 11),
#  ('參與', 11),
#  ('針對', 11),
#  ('行動', 11),
#  ('全球', 11),
#  ('無', 11),
#  ('導致', 11),
#  ('展開', 11),
#  ('團體', 11),
#  ('集團', 11),
#  ('美元', 11),
#  ('明年', 11),
#  ('議題', 10),
#  ('增加', 10),
#  ('死亡', 10),
#  ('所有', 10),
#  ('機場', 10),
#  ('部分', 10),
#  ('發出', 10),
#  ('使用', 10),
#  ('計畫', 10),
#  ('引發', 10),
#  ('歷史', 10),
#  ('主義', 10),
#  ('美食', 10),
#  ('建議', 9),
#  ('保護', 9),
#  ('化', 9),
#  ('努力', 9),
#  ('未能', 9),
#  ('回應', 9),
#  ('建立', 9),
#  ('成功', 9),
#  ('安排', 9)]

# %%
#整理出raw-data所有的雙連字( 不分類 )

All_Ftwowords2=[]
for n in lab_Ftwowords.values():
    for m in n:
        All_Ftwowords2.append(m)

All_Ftwowords = []
for w in All_Ftwowords2:
    All_Ftwowords.append(w[0])
All_Ftwowords
# Out:
# ['雙城論壇',
#  '兩岸關係',
#  '農業農村',
#  '短視頻',
#  '產業合作',
#  '豬瘟疫情',
#  '公眾妨擾',
#  '九二共識',
#  '兩岸企業家',
#  '兩岸經濟',
#  '報導引述',
#  '殭屍企業',
#  '立法會議員',
#  '新華社報導',
#  '城市交流',
#  '北京當局',
#  '美國之音',
#  '短影音',
#  '藏醫藥',
#  '企業家峰會',
#  '農村部',
#  '自由亞洲',
#  '亞洲電台',
#  '改革開放',
#  '台灣事務',
#  '事務辦公室',
#  '陳明祺',
#  '立方公尺微克',
#  '朱凱廸',
#  '上海市台辦',
#  '國家憲法',
#  '大文娛',
#  '楊偉東',
#  '兩岸城市',
#  '蔣永新',
#  '進口商品',
#  '新能源',
#  '營商環境',
#  '李文足',
#  '塗鴉牆',
#  '中國農業',
#  '大陸改革',
#  'RFID技術',
#  '占三子',
#  '煽惑公眾',
#  '脫貧攻堅',
#  '陸媒報導',
#  '台北上海',
#  '上海雙城',
#  '台辦官員',
#  '阿里大文',
#  '經濟增速',
#  '劉結一',
#  '黨報黨刊',
#  '裴金佳',
#  '台灣溫泉',
#  '龔小夏',
#  '經濟文化',
#  '頭死亡',
#  '死亡頭',
#  '大陸委員會',
#  '中國國內',
#  '妨擾煽惑',
#  '中共中央',
#  '辦公室主任',
#  '主任李文輝',
#  '香港特別',
#  '特別行政區',
#  '占運動',
#  '民營企業',
#  '人民幣兌',
#  '進口汽車',
#  '數據顯示',
#  '重汙染',
#  '鄉郊代表',
#  '溫泉美食',
#  '雄安新區',
#  '生祥樂隊',
#  '造紙企業',
#  '造紙產能',
#  'B站',
#  '奔跑中國',
#  '新潟米進口',
#  '海關總署',
#  '經貿關係',
#  '中美經貿',
#  '經濟形勢',
#  '一帶一路',
#  '交流合作',
#  '當前中國',
#  '于康震',
#  '排查出',
#  '查出非洲',
#  '存欄生豬',
#  '生豬頭',
#  '頭發病',
#  '發病頭',
#  '集體宣誓',
#  '電台報導',
#  '意識形態',
#  '陳志武',
#  '商業電台',
#  '中國國務院',
#  '結對認親',
#  '全國政協',
#  '主席汪洋',
#  '反恐維穩',
#  '從事許可',
#  '許可目的',
#  '目的不符',
#  '不符活動',
#  '總理李克強',
#  '經濟發展',
#  '失業人員',
#  '官方微博',
#  '官員來台',
#  '國際社會',
#  '貿易摩擦',
#  '大陸經濟',
#  '美元匯率',
#  '人民幣元',
#  '人民幣匯率',
#  '澎湃新聞',
#  '北京天津',
#  '黨員幹部',
#  '立法會選舉',
#  '泛民建制',
#  '教科書式',
#  '張家口',
#  '無組織',
#  '組織排放',
#  '提名無效',
#  '跨境電子',
#  '電子商務',
#  '商務零售',
#  '零售進口',
#  '交易限值',
#  '年度交易',
#  '製漿產能',
#  '能源汽車',
#  '舉行例行',
#  '日本新潟米',
#  '福島核事故',
#  '食品進口',
#  '縣食品',
#  '莫干山路',
#  '赤山監獄',
#  '馬克思主義',
#  '阿根廷川',
#  '今後時期',
#  '台條',
#  '中國福建省',
#  '福建省廈門市',
#  '創意產業',
#  '發展改革',
#  '改革委員會',
#  '疫情發生',
#  '中國動物',
#  '預防控制',
#  '控制中心',
#  '報告中國',
#  '無害化',
#  '化處理',
#  '律師宣誓',
#  '宣誓律師',
#  '大陸國台辦',
#  '符合條件',
#  '中共總書記',
#  '總書記習近平',
#  '作上述',
#  '英國金融時報',
#  '認為中國',
#  '債務處置',
#  '企業名單',
#  '串謀公眾',
#  '已連續',
#  '高層官員',
#  '指出新疆',
#  '少數民族',
#  '幹部職工',
#  '上海市台灣',
#  '學術研討會',
#  '穩定發展',
#  '橫店工作室',
#  '工作室會議',
#  '會議內容',
#  '中國全國',
#  '遭拒絕',
#  '宣傳教育',
#  '輪值總裁',
#  '國家主權',
#  '委員會主任',
#  '香港基本法',
#  '社會治理',
#  '主張香港',
#  '推動兩岸',
#  '兩岸企業',
#  '企業合作',
#  '經濟合作',
#  '中國原則',
#  '美國聯邦',
#  '美國進口',
#  '汽車關稅',
#  '加徵關稅',
#  '汙染過程',
#  '國務院台灣',
#  '國務院總理',
#  '經濟下滑',
#  '下滑壓力',
#  '幹部讀',
#  '讀黨報',
#  '確認眼神',
#  '濃度立方公尺',
#  '發表聲明',
#  '參選鄉郊',
#  '昨天裁定',
#  '選舉主任',
#  '兩岸工作',
#  '工作小組',
#  '兩岸交流',
#  '陳明通說',
#  '電台節目',
#  '廈門市委書記',
#  '住院收據',
#  '感染病人',
#  '台旅會北京',
#  '北京辦事處',
#  '鐵路安全',
#  '泰國警方',
#  '希望聲',
#  '國家稅務',
#  '稅務總局',
#  '工資薪金',
#  '薪金所得',
#  '減稅幅度',
#  '拜請保生',
#  '普通話組',
#  '學生領袖',
#  '河北盛華',
#  '全面退出',
#  '洞庭湖區',
#  '區造紙',
#  '平台管理',
#  '管理規範',
#  '中國網絡',
#  '網絡視聽',
#  '網絡短',
#  '視頻平台',
#  '能源車',
#  '外國車廠',
#  '指數PMI',
#  '回落百分點',
#  '價格指數',
#  '中國田徑',
#  '田徑協會',
#  '主權領土',
#  '領土完整',
#  '禁止日本',
#  '進口食品',
#  '食品飼料',
#  '中國央行',
#  '袁偉靜',
#  '提出探視',
#  '探視申請',
#  '空氣重',
#  '中方代表',
#  '美方代表',
#  '美關係',
#  '美國中國',
#  '問題進行',
#  '加強溝通',
#  '智慧財產權',
#  '財產權保護',
#  '國有企業',
#  '峰會中國',
#  '廈門市舉辦',
#  '綜合合作',
#  '合作交流',
#  '能源環保',
#  '環保節能',
#  '節能產業',
#  '中小企業合作',
#  '青年創業',
#  '生物科技',
#  '現代服務業',
#  '服務業暨',
#  '暨文化',
#  '文化創意',
#  '金融機構',
#  '包括兩岸',
#  '大陸發展',
#  '總體可控',
#  '部新聞',
#  '新聞辦公室',
#  '辦公室發布',
#  '合江縣',
#  '長安區',
#  '區北京市',
#  '官網公布',
#  '動物疫病',
#  '內政部移民署',
#  '相關法律',
#  '律師集體',
#  '戴佩清',
#  '依法治國',
#  '海外人士',
#  '中國社會',
#  '篇文章',
#  '經濟政治',
#  '研究所所長',
#  '香港新聞',
#  '新聞博覽館',
#  '香港媒體',
#  '兩岸當局',
#  '港澳台居民',
#  '測試發現',
#  '成功讀取',
#  '企業產能',
#  '產能企業',
#  '企業債務',
#  '網報導',
#  '國家發展',
#  '份通知',
#  '破產重整',
#  '家企業',
#  '陳日君',
#  '戴耀廷陳健民',
#  '陳健民朱耀明',
#  '公民抗命',
#  '西九龍',
#  '九龍裁判',
#  '裁判法院',
#  '包括占',
#  '議員邵家',
#  '邵家臻',
#  '臻陳淑莊',
#  '陳淑莊學運',
#  '學運領袖',
#  '領袖張秀賢',
#  '張秀賢鍾耀華',
#  '鍾耀華社會',
#  '社會民主',
#  '民主連線',
#  '連線副主席',
#  '副主席黃',
#  '黃浩銘',
#  '浩銘民主黨',
#  '民主黨立法會',
#  '議員李',
#  '李永達',
#  '永達控告',
#  '控告項',
#  '項罪名',
#  '罪名不等',
#  '不等包括',
#  '包括串謀',
#  '煽惑煽惑',
#  '停留時間',
#  '新疆教育營',
#  '強行入住',
#  '治疆方略',
#  '以來中國',
#  '政協主席',
#  '攻堅工作',
#  '教育培訓',
#  '新疆工作',
#  '中共新疆',
#  '相關人員',
#  '曾來台',
#  '活動雙城',
#  '主論壇',
#  '政府發言人',
#  '劉奕霆',
#  '中國大學',
#  '促進就業',
#  '失業保險費',
#  '就業局勢',
#  '下行壓力',
#  '壓力有所',
#  '有所加大',
#  '高度重視',
#  '放突出',
#  '突出位置',
#  '就業創業',
#  '目標任務',
#  '小微企業',
#  '下崗失業',
#  '稅收優惠',
#  '優惠政策',
#  '及時採取',
#  '陝西省西安市',
#  '西安市鄠邑',
#  '鄠邑區',
#  '北京市通州區',
#  '黑龍江省農墾',
#  '農墾總局',
#  '總局北安',
#  '北安管理局',
#  '知情人士',
#  '踩線申請',
#  '陸委會副主委',
#  '副主委陳',
#  '台北舉辦',
#  '遵守憲法',
#  '憲法宣傳',
#  '弘揚憲法',
#  '憲法精神',
#  '堅定不移',
#  '憲法權威',
#  '宗教信仰',
#  '阿里音樂',
#  '優酷土豆',
#  '請求引渡',
#  '陳同佳到',
#  '佳到台',
#  '台受審',
#  '相關部門',
#  '潘曉穎',
#  '陳同佳',
#  '一國原則',
#  '沈春耀',
#  '香港主權',
#  '主權轉移',
#  '北京方面',
#  '出席開幕式',
#  '大陸全國',
#  '變兩岸',
#  '台灣同胞書',
#  '同胞書發表',
#  '發表週年',
#  '匯率中間價',
#  '創以來',
#  '一段時間',
#  '在岸人民幣',
#  '元中國',
#  '濃度達到',
#  '達到重度',
#  '汙染水準',
#  '細懸浮微粒',
#  '發布大霧',
#  '大陸國務院',
#  '主任劉',
#  '中國商務部',
#  '確定因素',
#  '法制晚報',
#  '這是中國',
#  '問題事關',
#  '黨刊發行',
#  '業界人士',
#  '失去席',
#  '新故宮',
#  '故宮計畫',
#  '文化中心',
#  '台灣民報',
#  '柏林愛樂',
#  '藝術總監',
#  '劉育樹',
#  '台中國家',
#  '國家歌劇院',
#  '台灣文化',
#  '寺田尚樹',
#  '故宮北院',
#  '茱莉亞學院',
#  '藝術中心',
#  '北院整',
#  '整擴建',
#  '歐陽文津',
#  '電影看板',
#  '杜達美',
#  '歷史博物館',
#  '文學研究',
#  '金馬賓館',
#  '鄭淑麗',
#  '運動紀錄片',
#  '藝術文化',
#  '張龍雲',
#  '件作品',
#  '金點設計獎',
#  '英國國家',
#  '作家李維',
#  '黃永泰',
#  '衛武營音樂廳',
#  '台北國家',
#  '霹靂英雄',
#  '英雄戰紀',
#  '戰紀刀',
#  '刀異數',
#  '灌籃高手',
#  '歷史建築',
#  '姜阿新',
#  '國立故宮',
#  '故宮博物院',
#  '人魚紀',
#  '戶外轉播',
#  '小說集許涼涼',
#  '趙慕鶴',
#  '表演藝術',
#  '台灣作家',
#  '台灣文學',
#  '四分香港',
#  '楊牧文學',
#  '台北書展',
#  '相聲瓦舍',
#  '末代皇帝',
#  '結晶釉',
#  '周洪明雪',
#  '利文祺',
#  '布朗維爾',
#  '紐約茱莉亞',
#  '國家學術',
#  '音樂廳演出',
#  '祖賓梅塔',
#  '美麗佳人',
#  '國家兩廳院',
#  '高雄衛武營',
#  '衛武營國家',
#  '國家藝術',
#  '國光劇團',
#  '朱安麗',
#  '日治時期',
#  '國立台灣',
#  '文學作品',
#  '長篇小說',
#  '介紹台灣',
#  '台灣同人誌',
#  '台灣國際',
#  '東京國立',
#  '國立博物館',
#  '台灣文學館',
#  '書展基金會',
#  '瓜達拉哈拉書展',
#  '吉普賽女郎',
#  '菁凌晨',
#  '小說散文',
#  '彩虹眷村',
#  '行政院核定',
#  '世界文學',
#  '看板畫師',
#  '葡萄園式',
#  '帕胡德',
#  '生活甜蜜',
#  '黃翊工作室',
#  '國家戲劇院',
#  '衛武營藝術',
#  '金枝走演',
#  '文化藝術',
#  '黃慧美',
#  '評審委員',
#  '新世界',
#  '鋼琴大賽',
#  '社會運動',
#  '顏擇雅',
#  '作品包括',
#  '梵谷照片',
#  '梵谷博物館',
#  '動畫影集',
#  '報導文學',
#  '金點概念',
#  '概念設計獎',
#  '最佳設計獎',
#  '同人誌作品',
#  '國際藝術節',
#  '陳梓成',
#  '郭新林',
#  '文資審議',
#  '新洋樓',
#  '公共工程',
#  '顏真卿',
#  '祭姪文稿',
#  '整擴',
#  '擴建',
#  '張正傑',
#  '台灣文學獎',
#  '自由大學',
#  '馬賽克鑲嵌畫',
#  '國家工藝',
#  '工藝成就獎',
#  '雅加達歷史',
#  '普希金博物館',
#  '台灣學者',
#  '天津茱莉亞',
#  '學術院',
#  '手繪電影',
#  '式音樂廳',
#  '舉辦屆',
#  '共製計畫',
#  '總監簡文彬',
#  '這是一部',
#  '場演出',
#  '霹靂異數',
#  '屆台北',
#  '台新銀行',
#  '銀行文化',
#  '藝術基金會',
#  '推出台灣',
#  '誠品會員',
#  '歲歲',
#  '李尚軒',
#  '國家音樂廳',
#  '登錄歷史',
#  '文化資產',
#  '劉增鍇',
#  '模型寺',
#  '迷你小',
#  '童話故事',
#  'vanGogh',
#  '武俠兒童劇',
#  '種種',
#  '呂東熹',
#  '文化總會',
#  '之間關係',
#  '森林路',
#  '香港行山',
#  '劇場導演',
#  '鳴海康',
#  '設計獎金點',
#  '設計獎年度',
#  '腹語師的',
#  '師的女兒',
#  '處文化',
#  '文化組',
#  '藝術博物館',
#  '雷鬼音樂',
#  '專欄作家',
#  '梓成古厝',
#  '客家委員會',
#  '卿祭姪',
#  '故宮副院長',
#  '指出故宮',
#  '首任館長',
#  '館長林瑞明',
#  '入圍名單',
#  '最佳現代舞',
#  '演出衛武營',
#  '雙年展台灣館',
#  '普雷西亞',
#  '幅作品',
#  '幅畫作',
#  '黃崇凱',
#  '作家作品',
#  '羅馬家',
#  '精演新',
#  '新老戲',
#  '後勁王建民',
#  '物怪里',
#  '曾經美麗',
#  '天上人間',
#  '人間李後主',
#  '中心舉辦',
#  '台語散文',
#  '客語散文',
#  '原住民漢語',
#  '漢語散文',
#  '散文金典獎',
#  '奇幻小說',
#  '熊夜鶯',
#  '作品已',
#  '種語言',
#  '台北文學獎',
#  '劉耕名',
#  '多羅磨',
#  '普普藝術',
#  '金寶湯',
#  '湯罐頭',
#  '神話故事',
#  '歐羅芭',
#  '俄羅斯普希金',
#  '圖書文獻',
#  '東方圖書館',
#  '故宮內部',
#  '整修期間',
#  '故宮院長',
#  '文祺布朗',
#  '大學預科',
#  '預科課程',
#  '倫敦大學',
#  '大學亞非',
#  '亞非學院',
#  '阿拉伯文學',
#  '交流中心',
#  '堅持手繪',
#  '愛樂今晚',
#  '戶外劇場',
#  '號交響曲',
#  '南烏拉爾',
#  '翻譯成日文',
#  '香港作家',
#  '李維菁驟',
#  '菁驟逝',
#  '透過臉書',
#  '凌晨時許',
#  '時許病逝',
#  '病逝台大',
#  '醫院享年',
#  '病逝訊息',
#  '訊息家屬',
#  '佳人編輯部',
#  '長笛四重奏',
#  '北院正館',
#  '油畫為主',
#  '鋼雕藝術節',
#  '現地創作',
#  '創作靈感',
#  '台灣藝術家',
#  '國家表演',
#  '三館共製',
#  '工作室長路',
#  '台灣創作',
#  '走演美麗',
#  '美麗台灣',
#  '演出場',
#  '單口配音',
#  '配音霹靂',
#  '角色配音',
#  '低音協奏曲',
#  '紀念曲',
#  '感謝台北',
#  '外交部文化部',
#  '軟實力',
#  '推廣台灣',
#  '台灣香港',
#  '國際身障',
#  '身障鋼琴',
#  '來自國',
#  '鋼琴家參賽',
#  '中心舉行',
#  '台灣身心',
#  '障礙音樂',
#  '音樂關懷',
#  '關懷協會',
#  '協會理事長',
#  '年代台灣',
#  '台灣台灣',
#  '政治社會',
#  '台史博',
#  '社會議題',
#  '基金會執行長',
#  '年度暢銷',
#  '漫畫灌籃',
#  '人際關係',
#  '類書籍',
#  '讀者共鳴',
#  '集集樟腦',
#  '樟腦出張',
#  '修復利用',
#  '樟腦產業',
#  '紙模型',
#  '建築模型',
#  '接受專訪',
#  '藝術作品',
#  '海外展出',
#  '巴黎羅浮宮',
#  '每月首',
#  '免費開放',
#  '青少年圖書',
#  '弟弟西奧',
#  '世界各地',
#  '漫畫家葉宏甲',
#  '五年級生',
#  '紙風車劇團',
#  '哨角製作',
#  '獲得貢獻獎',
#  '擔檜木',
#  '中華文化',
#  '曾獲',
#  '文學類',
#  '作家劉克襄',
#  '走往森林',
#  '香港劉克襄',
#  '華人作家',
#  '珈啡時光',
#  '劇場作品',
#  '已完成',
#  '海康平',
#  '日起台北',
#  '劇場演出',
#  '亞洲動漫展',
#  '東南亞國家',
#  '參與項',
#  '鄭文福',
#  '人文社會',
#  '舉辦台灣',
#  '陳彥豪',
#  '林滿秋',
#  '駐英代表',
#  '讀者介紹',
#  '首海外',
#  'ofthe',
#  '全球巡迴展',
#  '展覽吸引',
#  'Museumof',
#  '來訪神',
#  '神面具',
#  '面具扮裝',
#  '扮裝眾神',
#  '列入非',
#  '彩繪大師',
#  '大師郭',
#  '文資審查',
#  '彰化縣文化局',
#  '新林彩繪',
#  '彩繪作品',
#  '審議委員',
#  '蕭文杰',
#  '風華再現',
#  '工程委員會',
#  '立法院教委會',
#  '認為故宮',
#  '建計畫',
#  '文稿懷素',
#  '懷素敘帖',
#  '博物館展出',
#  '立委柯志恩',
#  '海報文宣',
#  '全銜國立',
#  '博物院載示',
#  '文學館首任',
#  '市政會議',
#  '台南文化',
#  '審查委員',
#  '瑟希出版社',
#  '台灣詩',
#  '年到年間',
#  '大學Universite',
#  '文學大獎',
#  '最佳展位',
#  '中型展位',
#  '借展交流',
#  '故宮典藏',
#  '故宮故宮',
#  '國際文化',
#  '當代藝術',
#  '往前走',
#  '御盟集團',
#  '大提琴家張',
#  '左手受傷',
#  '國家舞蹈',
#  '舞蹈獎',
#  '現代舞編舞',
#  '林懷民舞作',
#  '舞作精選',
#  '毛月亮',
#  '中心藝術',
#  '威尼斯雙年展',
#  '生日願望',
#  '願望影片',
#  '木石圖',
#  '崇凱自由',
#  '名導演',
#  '巴黎最後',
#  '最後探戈',
#  '影展獲頒',
#  '夜長夢多異境',
#  '異境重返',
#  '重返求生',
#  '求生計畫',
#  '彩排記者會',
#  '古羅馬時期',
#  '深邃眼眸',
#  '流落海外',
#  '馬賽克地板',
#  '澤烏瑪',
#  '馬賽克博物館',
#  '支紀錄片',
#  '梁國新',
#  '台星藝術家',
#  '再現劇團',
#  '趙雅芬',
#  '大小周后',
#  '委員嚴謹',
#  '決審會議',
#  '台灣工藝',
#  '晶釉畫',
#  '得獎名單',
#  '劇本台語',
#  '散文客語',
#  '散文原住民',
#  '典禮揭曉',
#  '文學獎頒獎',
#  '故事裡',
#  '幻想故事',
#  '國際聲樂',
#  '傳統表演',
#  '歌仔戲電影',
#  '李瑾倫與',
#  '墨西哥瓜達拉哈拉',
#  '阿飛正轉',
#  '舞蹈戲劇',
#  '無伴奏',
#  '伴奏人聲',
#  '階段決審',
#  '台北文學',
#  '自然知道',
#  '台灣原住民族',
#  '西拉雅語言',
#  '巽他王國',
#  '荷蘭殖民',
#  '殖民時期',
#  '荷蘭東印度',
#  '東印度公司',
#  '磨王國',
#  '呈現沃荷',
#  '惠特尼博物館',
#  '沃荷年代',
#  '類比科',
#  '智慧機械',
#  '投資抵減',
#  '愛講',
#  '機械投資',
#  '歐元區',
#  '公開收購',
#  '中國製造',
#  '醫療產業',
#  '業務外包',
#  '致新',
#  '收購類比',
#  '新台幣兌',
#  '精準醫療',
#  '出門問問',
#  '歐元',
#  '抵減方案',
#  '租稅優惠',
#  '公務機關',
#  '次長龔明鑫',
#  '主計總處',
#  '經濟成長率',
#  '國產建材',
#  '阮春福',
#  '集邦科技',
#  '科已',
#  '已發行',
#  '發行普通股',
#  '低漲幅',
#  '外匯交易員',
#  '樂天Kobo',
#  '金融科技',
#  '影視作品',
#  '乾貯設施',
#  '吳舜文',
#  '智慧機器人',
#  '外包公司',
#  '手機市場',
#  '辦租金',
#  '海外市場',
#  '核心CPI',
#  '徐健中',
#  '現代汽車',
#  '市場新台幣',
#  '資本適足',
#  '貿易戰休兵',
#  '商務簽證',
#  '薩克馮',
#  '馮賽卡',
#  '口碑分享',
#  '黃背心',
#  '基士德科技',
#  '黃逸斌',
#  '李玉鼎',
#  '萬元萬元',
#  '進口貨物',
#  '全球人壽',
#  '中央銀行',
#  '謝南強',
#  '超過成',
#  '機械相關',
#  '相關應用',
#  '經濟部政務',
#  '政務次長',
#  '元年增',
#  '貿易戰暫時',
#  '暫時休兵',
#  '因素影響',
#  '租金行情',
#  '信義房屋',
#  '同業公會',
#  '核養綠',
#  '已成為',
#  '台灣市場',
#  '立法院財政',
#  '財政委員會',
#  '期貨交易法',
#  '文在寅',
#  '高元',
#  '元低',
#  '低元',
#  '適足率',
#  '台商回流',
#  '台灣旅客',
#  '除役作業',
#  '歐盟各國',
#  '項提案',
#  '美國大豆',
#  '污水處理',
#  '習近平阿根廷',
#  '決策小組',
#  '放款餘額',
#  '冷凍食品',
#  '泓順投資',
#  '愛德萬',
#  '短期業務',
#  ...]

# %%
import random

# %%
random.shuffle(books)

# %%
def pos_features(article,top):
    
    ftwowords = [w[0] for v in lab_Ftwowords.values()  for w in v]
    fwords = [w[0] for v in lab_fwords.values()  for w in v]
    
    
    features={}
    t = ''
    seg_list = jieba.cut_for_search(article)
    t = ",".join(seg_list)
    article_tokens = t.split(',')
    article_tokens = [w for w in article_tokens if w.isalpha()]
    
    
    
    
    filt_tokens = list(filter(lambda a: a not in stopwords and a not in filterwords , article_tokens))
    toks = [w[0] for w in nltk.FreqDist(filt_tokens).most_common(top)]
    for tok in toks:
        if tok in fwords:
            features[tok] = True 

    

    twowords = list(nltk.bigrams(article_tokens))
    alltwowords2 = [i[0]+i[1] for i in twowords]
    intwowords = [two for two in alltwowords2 if two in All_Ftwowords]
    ftwowords = nltk.FreqDist(intwowords).most_common(int(top))
    for i in ftwowords:
        w = i[0]
        if w in ftwowords:
            features[w] = True

            

    return features

# %%
def get_featuresets(books,top=200):
    n = 0
    featuresets=[]
    for book in books:
        article = book[0]
        labname = book[1]
        features = pos_features(article,top)
        feature_item = (features,labname)
        featuresets.append(feature_item)
        n += 1
        if n % 20 == 0:
            print(n,end=',')

    return featuresets

# %%
featuresets = get_featuresets(books,200)
# Out:
# 20,40,60,80,100,120,140,160,180,200,220,240,260,280,300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660,680,700,720,740,760,780,800,820,840,860,880,900,920,940,960,980,1000,1020,1040,1060,1080,1100,1120,1140,1160,1180,1200,

# %%
featuresets[1:30]
# Out:
# [({'一路': True,
#    '中國': True,
#    '中心': True,
#    '以上': True,
#    '以來': True,
#    '任務': True,
#    '先前': True,
#    '公司': True,
#    '公斤': True,
#    '凌晨': True,
#    '分': True,
#    '包括': True,
#    '去年': True,
#    '國家': True,
#    '地區': True,
#    '地球': True,
#    '執行': True,
#    '報導': True,
#    '增加': True,
#    '大陸': True,
#    '完成': True,
#    '工程': True,
#    '已': True,
#    '度': True,
#    '指出': True,
#    '攜手': True,
#    '方式': True,
#    '星': True,
#    '服務': True,
#    '消息': True,
#    '火箭': True,
#    '發射': True,
#    '直接': True,
#    '研究': True,
#    '研究院': True,
#    '科技': True,
#    '系列': True,
#    '系統': True,
#    '綜合': True,
#    '號': True,
#    '衛星': True,
#    '設備': True,
#    '軌道': True,
#    '送入': True,
#    '運載': True,
#    '部': True,
#    '陸媒': True,
#    '集團': True,
#    '顆': True,
#    '高': True},
#   '科技'),
#  ({'主演': True,
#    '令': True,
#    '先生': True,
#    '公司': True,
#    '共同': True,
#    '冠軍': True,
#    '創下': True,
#    '南韓': True,
#    '吸引': True,
#    '女兒': True,
#    '指出': True,
#    '播出': True,
#    '收視': True,
#    '政治': True,
#    '故事': True,
#    '數據': True,
#    '新聞': True,
#    '明星': True,
#    '昨晚': True,
#    '晚間': True,
#    '朋友': True,
#    '期待': True,
#    '李': True,
#    '歷年': True,
#    '發布': True,
#    '發生': True,
#    '紀錄': True,
#    '聯合': True,
#    '觀眾': True,
#    '調查': True,
#    '通訊': True,
#    '集': True,
#    '電視': True,
#    '青年': True,
#    '領先': True,
#    '高': True,
#    '高達': True},
#   '娛樂'),
#  ({'一場': True,
#    '一起': True,
#    '上台': True,
#    '不斷': True,
#    '之後': True,
#    '人生': True,
#    '伍思凱': True,
#    '全場': True,
#    '公司': True,
#    '參加': True,
#    '只': True,
#    '回憶': True,
#    '地區': True,
#    '場': True,
#    '太': True,
#    '媒體': True,
#    '學生': True,
#    '學習': True,
#    '導致': True,
#    '小時': True,
#    '巡迴': True,
#    '市場': True,
#    '帶領': True,
#    '度': True,
#    '愛': True,
#    '感謝': True,
#    '所有': True,
#    '故事': True,
#    '新創': True,
#    '日前': True,
#    '曾': True,
#    '最後': True,
#    '最終': True,
#    '期待': True,
#    '歌手': True,
#    '歌曲': True,
#    '歲': True,
#    '活動': True,
#    '海外': True,
#    '演唱': True,
#    '演唱會': True,
#    '熱情': True,
#    '父親': True,
#    '特別': True,
#    '生命': True,
#    '當天': True,
#    '發展': True,
#    '突然': True,
#    '節目': True,
#    '終場': True,
#    '老師': True,
#    '至今': True,
#    '舞台': True,
#    '英文': True,
#    '觀眾': True,
#    '計畫': True,
#    '談到': True,
#    '責任': True,
#    '走': True,
#    '辦': True,
#    '近年': True,
#    '進一步': True,
#    '達到': True,
#    '金曲': True,
#    '鋼琴': True,
#    '陳': True,
#    '面對': True,
#    '音樂': True,
#    '餐廳': True,
#    '首': True,
#    '馬來西亞': True},
#   '娛樂'),
#  ({'一直': True,
#    '一間': True,
#    '世界': True,
#    '中國': True,
#    '亞洲': True,
#    '人士': True,
#    '位於': True,
#    '來自': True,
#    '內容': True,
#    '分': True,
#    '包括': True,
#    '北京': True,
#    '協助': True,
#    '友人': True,
#    '受到': True,
#    '台商': True,
#    '司法': True,
#    '名': True,
#    '國家': True,
#    '國際': True,
#    '地方': True,
#    '報導': True,
#    '壓力': True,
#    '多年': True,
#    '大陸': True,
#    '學員': True,
#    '宗教': True,
#    '寫': True,
#    '居民': True,
#    '已': True,
#    '已經': True,
#    '希望': True,
#    '幫助': True,
#    '廣播': True,
#    '成功': True,
#    '指': True,
#    '指出': True,
#    '指控': True,
#    '擁有': True,
#    '政府': True,
#    '文化': True,
#    '文字': True,
#    '新聞': True,
#    '曾': True,
#    '最近': True,
#    '東南亞': True,
#    '正在': True,
#    '法律': True,
#    '泰國': True,
#    '涉': True,
#    '涉及': True,
#    '為主': True,
#    '無': True,
#    '營運': True,
#    '獲得': True,
#    '當地': True,
#    '當局': True,
#    '發射': True,
#    '目前': True,
#    '相關': True,
#    '知名': True,
#    '知道': True,
#    '稱': True,
#    '突破': True,
#    '管理': True,
#    '節目': True,
#    '美國': True,
#    '自由': True,
#    '蔣': True,
#    '處理': True,
#    '製作': True,
#    '設立': True,
#    '認為': True,
#    '調查': True,
#    '警方': True,
#    '負責': True,
#    '負責人': True,
#    '貢獻': True,
#    '資料': True,
#    '透過': True,
#    '進行': True,
#    '過去': True,
#    '違反': True,
#    '遭': True,
#    '部': True,
#    '重要': True,
#    '離開': True,
#    '電台': True},
#   '兩岸'),
#  ({'三振': True,
#    '上壘': True,
#    '二壘': True,
#    '交易': True,
#    '人士': True,
#    '保持': True,
#    '億美': True,
#    '元': True,
#    '全壘打': True,
#    '公布': True,
#    '出現': True,
#    '出賽': True,
#    '分': True,
#    '勝': True,
#    '勝利': True,
#    '卡諾': True,
#    '名': True,
#    '報導': True,
#    '場': True,
#    '多年': True,
#    '大聯盟': True,
#    '大都會': True,
#    '季': True,
#    '完成': True,
#    '小': True,
#    '尚未': True,
#    '尼克': True,
#    '局': True,
#    '度': True,
#    '引述': True,
#    '情況': True,
#    '成': True,
#    '成功': True,
#    '戰績': True,
#    '打擊': True,
#    '打球': True,
#    '打點': True,
#    '投': True,
#    '投手': True,
#    '投球': True,
#    '拒絕': True,
#    '拿到': True,
#    '指數': True,
#    '提供': True,
#    '擔任': True,
#    '攻擊': True,
#    '放棄': True,
#    '效力': True,
#    '救援': True,
#    '敗': True,
#    '整體': True,
#    '明星': True,
#    '明顯': True,
#    '是否': True,
#    '曾': True,
#    '未': True,
#    '未來': True,
#    '條例': True,
#    '條款': True,
#    '模式': True,
#    '歲': True,
#    '王建民': True,
#    '現金': True,
#    '當時': True,
#    '筆': True,
#    '紀錄': True,
#    '紐約': True,
#    '結束': True,
#    '美元': True,
#    '美國': True,
#    '聯盟': True,
#    '職棒': True,
#    '能否': True,
#    '萬': True,
#    '衰退': True,
#    '認為': True,
#    '送出': True,
#    '透過': True,
#    '進入': True,
#    '達': True,
#    '違反': True,
#    '遭': True,
#    '野手': True,
#    '金額': True,
#    '開心': True,
#    '關鍵': True,
#    '防禦率': True,
#    '隊友': True,
#    '領先': True,
#    '頻道': True},
#   '運動'),
#  ({'一起': True,
#    '世界': True,
#    '主義': True,
#    '人物': True,
#    '代表': True,
#    '件': True,
#    '位': True,
#    '作品': True,
#    '作家': True,
#    '使用': True,
#    '全球': True,
#    '兩人': True,
#    '公布': True,
#    '出生': True,
#    '創作': True,
#    '包括': True,
#    '參展': True,
#    '台北': True,
#    '台灣館': True,
#    '報告': True,
#    '宣布': True,
#    '實際': True,
#    '屆': True,
#    '展覽': True,
#    '巴黎': True,
#    '帶領': True,
#    '式': True,
#    '影片': True,
#    '性別': True,
#    '應用': True,
#    '擔任': True,
#    '政治': True,
#    '新聞': True,
#    '日常': True,
#    '明年': True,
#    '曾': True,
#    '歐洲': True,
#    '歷史': True,
#    '段': True,
#    '民眾': True,
#    '法國': True,
#    '法庭': True,
#    '淑麗': True,
#    '獲': True,
#    '生活': True,
#    '當代': True,
#    '發展': True,
#    '監視器': True,
#    '真實': True,
#    '研究': True,
#    '社會': True,
#    '科技': True,
#    '種': True,
#    '空間': True,
#    '紐約': True,
#    '結合': True,
#    '網路': True,
#    '罪': True,
#    '美國': True,
#    '美術': True,
#    '美術館': True,
#    '義大利': True,
#    '藝術': True,
#    '藝術家': True,
#    '行動': True,
#    '裝置': True,
#    '製作': True,
#    '角度': True,
#    '評論': True,
#    '認為': True,
#    '議題': True,
#    '資料': True,
#    '身體': True,
#    '連結': True,
#    '運算': True,
#    '邀請': True,
#    '鄭': True,
#    '重新': True,
#    '關注': True,
#    '關鍵': True,
#    '電子': True,
#    '電影': True,
#    '電腦': True,
#    '領袖': True,
#    '首': True},
#   '文化'),
#  ({'中國': True,
#    '企業': True,
#    '公司': True,
#    '公布': True,
#    '北京': True,
#    '占': True,
#    '取得': True,
#    '同意': True,
#    '增加': True,
#    '外資': True,
#    '委員': True,
#    '委員會': True,
#    '家': True,
#    '實施': True,
#    '已': True,
#    '成為': True,
#    '投資': True,
#    '持有': True,
#    '持股': True,
#    '指出': True,
#    '掌握': True,
#    '擴大': True,
#    '收購': True,
#    '放寬': True,
#    '新': True,
#    '日本': True,
#    '核准': True,
#    '法規': True,
#    '準備': True,
#    '獲': True,
#    '當地': True,
#    '當局': True,
#    '發布': True,
#    '發表': True,
#    '目前': True,
#    '相關': True,
#    '管理': True,
#    '經濟': True,
#    '聲明': True,
#    '股權': True,
#    '規定': True,
#    '證券': True,
#    '責任': True,
#    '資本': True,
#    '辦法': True,
#    '近期': True,
#    '這是': True,
#    '進一步': True,
#    '金融': True,
#    '銀行': True,
#    '開放': True,
#    '限制': True,
#    '集團': True,
#    '首': True},
#   '兩岸'),
#  ({'上述': True,
#    '並未': True,
#    '中共': True,
#    '中國': True,
#    '中心': True,
#    '主義': True,
#    '主辦': True,
#    '事': True,
#    '亞軍': True,
#    '儀式': True,
#    '全國': True,
#    '再度': True,
#    '冠軍': True,
#    '加強': True,
#    '動員': True,
#    '協會': True,
#    '卻': True,
#    '名': True,
#    '單位': True,
#    '國家': True,
#    '國際': True,
#    '執行': True,
#    '培養': True,
#    '報導': True,
#    '大陸': True,
#    '奪冠': True,
#    '女子': True,
#    '媒體': True,
#    '存在': True,
#    '完全': True,
#    '專業': True,
#    '尊重': True,
#    '工作': True,
#    '差': True,
#    '度': True,
#    '引發': True,
#    '影片': True,
#    '影響': True,
#    '志工': True,
#    '感謝': True,
#    '批評': True,
#    '抵達': True,
#    '提出': True,
#    '改變': True,
#    '新聞': True,
#    '昨天': True,
#    '最後': True,
#    '會議': True,
#    '李': True,
#    '正': True,
#    '正常': True,
#    '比賽': True,
#    '活動': True,
#    '營運': True,
#    '爭取': True,
#    '獲得': True,
#    '理由': True,
#    '發出': True,
#    '相當': True,
#    '相關': True,
#    '社群': True,
#    '秒': True,
#    '種': True,
#    '突然': True,
#    '站': True,
#    '管理': True,
#    '精神': True,
#    '系列': True,
#    '紛紛': True,
#    '組織': True,
#    '網民': True,
#    '總局': True,
#    '舉行': True,
#    '行為': True,
#    '表達': True,
#    '要求': True,
#    '規範': True,
#    '評論': True,
#    '負責': True,
#    '負責人': True,
#    '質疑': True,
#    '賽事': True,
#    '辦法': True,
#    '透過': True,
#    '這是': True,
#    '通知': True,
#    '進一步': True,
#    '進行': True,
#    '運動': True,
#    '遭': True,
#    '選手': True,
#    '部分': True,
#    '集團': True,
#    '非洲': True,
#    '面對': True,
#    '順利': True,
#    '顯示': True},
#   '兩岸'),
#  ({'下午': True,
#    '中心': True,
#    '作品': True,
#    '俄羅斯': True,
#    '全': True,
#    '公尺': True,
#    '公里': True,
#    '出現': True,
#    '分': True,
#    '分鐘': True,
#    '包括': True,
#    '升空': True,
#    '南韓': True,
#    '只': True,
#    '報導': True,
#    '太空': True,
#    '引擎': True,
#    '成功': True,
#    '推進': True,
#    '新聞': True,
#    '日報': True,
#    '時間': True,
#    '核心': True,
#    '正常': True,
#    '消息': True,
#    '火箭': True,
#    '發射': True,
#    '目標': True,
#    '研究': True,
#    '研究院': True,
#    '科技': True,
#    '秒': True,
#    '穩定': True,
#    '系統': True,
#    '聯合': True,
#    '舉行': True,
#    '航空': True,
#    '號': True,
#    '表現': True,
#    '設計': True,
#    '這是': True,
#    '通訊': True,
#    '進行': True,
#    '運載': True,
#    '達到': True,
#    '部': True,
#    '重': True,
#    '長': True,
#    '開發': True,
#    '韓國': True,
#    '飛行': True,
#    '高興': True,
#    '高點': True},
#   '科技'),
#  ({'了解': True,
#    '健康': True,
#    '元': True,
#    '公司': True,
#    '分': True,
#    '參加': True,
#    '單位': True,
#    '嘉義': True,
#    '嘉義市': True,
#    '回應': True,
#    '執行': True,
#    '報導': True,
#    '增加': True,
#    '好': True,
#    '實際': True,
#    '導致': True,
#    '小': True,
#    '市長': True,
#    '座談': True,
#    '弱勢': True,
#    '強調': True,
#    '情形': True,
#    '意見': True,
#    '感受': True,
#    '成本': True,
#    '指': True,
#    '指出': True,
#    '推動': True,
#    '提到': True,
#    '提高': True,
#    '政府': True,
#    '政策': True,
#    '敗選': True,
#    '新': True,
#    '昨天': True,
#    '期待': True,
#    '檢討': True,
#    '民意': True,
#    '民眾': True,
#    '民進黨': True,
#    '民間': True,
#    '為例': True,
#    '當時': True,
#    '發言': True,
#    '發言人': True,
#    '相關': True,
#    '研發': True,
#    '立委': True,
#    '經濟': True,
#    '總統': True,
#    '聽到': True,
#    '英文': True,
#    '蔡': True,
#    '蔡英文': True,
#    '討論': True,
#    '認為': True,
#    '調漲': True,
#    '負擔': True,
#    '身體': True,
#    '轉述': True,
#    '辦法': True,
#    '進一步': True,
#    '部': True,
#    '長照': True,
#    '類': True,
#    '高': True},
#   '政治'),
#  ({'中國': True,
#    '亞洲': True,
#    '來到': True,
#    '個體': True,
#    '傅榆': True,
#    '兩岸': True,
#    '典禮': True,
#    '再次': True,
#    '創作': True,
#    '卻': True,
#    '原本': True,
#    '台灣人': True,
#    '國家': True,
#    '國際': True,
#    '執導': True,
#    '多元': True,
#    '尊重': True,
#    '導演': True,
#    '屆': True,
#    '工作': True,
#    '希望': True,
#    '影人': True,
#    '影帝': True,
#    '得獎': True,
#    '感到': True,
#    '所有': True,
#    '打造': True,
#    '批評': True,
#    '政治': True,
#    '文化': True,
#    '昨晚': True,
#    '最佳': True,
#    '最後': True,
#    '民主': True,
#    '民眾': True,
#    '涂': True,
#    '熱情': True,
#    '特別': True,
#    '獎項': True,
#    '獨立': True,
#    '獲': True,
#    '獲得': True,
#    '當成': True,
#    '發言': True,
#    '看待': True,
#    '真正': True,
#    '紀錄': True,
#    '紀錄片': True,
#    '網友': True,
#    '臉書': True,
#    '自由': True,
#    '致詞': True,
#    '舉行': True,
#    '落幕': True,
#    '藝術': True,
#    '言論': True,
#    '許多': True,
#    '請': True,
#    '身為': True,
#    '這是': True,
#    '鄭麗君': True,
#    '金馬': True,
#    '金馬獎': True,
#    '隨即': True,
#    '電影': True,
#    '青春': True,
#    '頒獎': True,
#    '願望': True},
#   '娛樂'),
#  ({'一直': True,
#    '一部': True,
#    '不足': True,
#    '並未': True,
#    '乾式': True,
#    '位': True,
#    '依據': True,
#    '保守': True,
#    '保持': True,
#    '修正': True,
#    '做出': True,
#    '全': True,
#    '公告': True,
#    '公尺': True,
#    '公里': True,
#    '北市': True,
#    '卻': True,
#    '去年': True,
#    '只': True,
#    '台': True,
#    '台電': True,
#    '地區': True,
#    '執照': True,
#    '執行': True,
#    '執行長': True,
#    '委員': True,
#    '委員會': True,
#    '安全': True,
#    '完工': True,
#    '審查': True,
#    '專業': True,
#    '導致': True,
#    '尤其': True,
#    '工作': True,
#    '工程': True,
#    '市府': True,
#    '市政府': True,
#    '年起': True,
#    '廢料': True,
#    '建置': True,
#    '影響': True,
#    '意見': True,
#    '成為': True,
#    '技術': True,
#    '指出': True,
#    '提出': True,
#    '擔心': True,
#    '政府': True,
#    '新': True,
#    '新北': True,
#    '施工': True,
#    '是否': True,
#    '暫時': True,
#    '未': True,
#    '核': True,
#    '核一': True,
#    '核一廠': True,
#    '核准': True,
#    '核能': True,
#    '標準': True,
#    '機關': True,
#    '民國': True,
#    '氣候': True,
#    '水土': True,
#    '溝通': True,
#    '現場': True,
#    '環境': True,
#    '疑慮': True,
#    '發生': True,
#    '發言': True,
#    '發言人': True,
#    '確認': True,
#    '程序': True,
#    '穩定': True,
#    '立場': True,
#    '範圍': True,
#    '組': True,
#    '經濟': True,
#    '經濟部': True,
#    '舉行': True,
#    '號機': True,
#    '行政': True,
#    '行政院': True,
#    '計畫': True,
#    '記者會': True,
#    '設施': True,
#    '設計': True,
#    '許多': True,
#    '評估': True,
#    '說明': True,
#    '調查': True,
#    '請': True,
#    '貯存': True,
#    '農業': True,
#    '近年': True,
#    '透過': True,
#    '造成': True,
#    '過程': True,
#    '達': True,
#    '重新': True,
#    '長': True,
#    '開展': True,
#    '除役': True,
#    '需求': True,
#    '面臨': True,
#    '項': True},
#   '地方'),
#  ({'一定': True,
#    '世界': True,
#    '中央': True,
#    '主辦': True,
#    '作品': True,
#    '使用': True,
#    '來自': True,
#    '元': True,
#    '充滿': True,
#    '內容': True,
#    '公司': True,
#    '共同': True,
#    '分鐘': True,
#    '動畫': True,
#    '原創': True,
#    '去年': True,
#    '受': True,
#    '只': True,
#    '台北': True,
#    '台南': True,
#    '合作': True,
#    '名': True,
#    '呈現': True,
#    '問題': True,
#    '國立': True,
#    '團隊': True,
#    '執行': True,
#    '執行長': True,
#    '奪下': True,
#    '媒體': True,
#    '季': True,
#    '宣導': True,
#    '導演': True,
#    '小': True,
#    '左右': True,
#    '希望': True,
#    '平台': True,
#    '平均': True,
#    '年輕': True,
#    '影片': True,
#    '影音': True,
#    '思考': True,
#    '愛': True,
#    '所有': True,
#    '手機': True,
#    '打造': True,
#    '扮演': True,
#    '指': True,
#    '指導': True,
#    '推出': True,
#    '推廣': True,
#    '提到': True,
#    '提名': True,
#    '播出': True,
#    '播映': True,
#    '支': True,
#    '支持': True,
#    '政府': True,
#    '故事': True,
#    '文化': True,
#    '文化部': True,
#    '斯': True,
#    '新': True,
#    '新台幣': True,
#    '方式': True,
#    '日本': True,
#    '時間': True,
#    '更多': True,
#    '期待': True,
#    '機會': True,
#    '獨立': True,
#    '獲': True,
#    '現代': True,
#    '理念': True,
#    '環境': True,
#    '生活': True,
#    '發揮': True,
#    '相當': True,
#    '盼': True,
#    '短片': True,
#    '社區': True,
#    '約': True,
#    '經費': True,
#    '網路': True,
#    '總體': True,
#    '考量': True,
#    '舉行': True,
#    '製作': True,
#    '角色': True,
#    '計畫': True,
#    '認識': True,
#    '議題': True,
#    '辛苦': True,
#    '透過': True,
#    '透露': True,
#    '過程': True,
#    '重新': True,
#    '重視': True,
#    '長片': True,
#    '關注': True,
#    '限制': True,
#    '陳': True,
#    '集': True,
#    '雲林': True,
#    '電視': True,
#    '電視台': True,
#    '非': True,
#    '面對': True,
#    '預計': True,
#    '題材': True,
#    '館長': True},
#   '娛樂'),
#  ({'一直': True,
#    '一路': True,
#    '丁寧': True,
#    '上台': True,
#    '世界': True,
#    '今晚': True,
#    '代表': True,
#    '做': True,
#    '入圍': True,
#    '典禮': True,
#    '出現': True,
#    '出道': True,
#    '力量': True,
#    '包括': True,
#    '化解': True,
#    '台': True,
#    '台北': True,
#    '同志': True,
#    '問題': True,
#    '國父': True,
#    '城市': True,
#    '奪下': True,
#    '女': True,
#    '好': True,
#    '尊重': True,
#    '小': True,
#    '屆': True,
#    '已經': True,
#    '幫助': True,
#    '平權': True,
#    '幸福': True,
#    '張': True,
#    '形式': True,
#    '影后': True,
#    '惠英紅': True,
#    '愛': True,
#    '感謝': True,
#    '成為': True,
#    '所有': True,
#    '擊敗': True,
#    '改變': True,
#    '暴力': True,
#    '最佳': True,
#    '朋友': True,
#    '期待': True,
#    '演員': True,
#    '激動': True,
#    '熱門': True,
#    '爭取': True,
#    '特別': True,
#    '獎項': True,
#    '獲獎': True,
#    '笑說': True,
#    '紀念館': True,
#    '紅毯': True,
#    '緊張': True,
#    '舉行': True,
#    '視為': True,
#    '配角': True,
#    '金馬': True,
#    '金馬獎': True,
#    '需要': True,
#    '頒獎': True,
#    '飾演': True},
#   '娛樂'),
#  ({'人物': True,
#    '作品': True,
#    '作家': True,
#    '傑出': True,
#    '出版': True,
#    '出生': True,
#    '創作': True,
#    '區': True,
#    '參與': True,
#    '台南': True,
#    '台南市': True,
#    '單位': True,
#    '國內': True,
#    '國立': True,
#    '大學': True,
#    '委員': True,
#    '學術': True,
#    '審查': True,
#    '市府': True,
#    '市民': True,
#    '成功': True,
#    '指出': True,
#    '擁有': True,
#    '擔任': True,
#    '政府': True,
#    '文化': True,
#    '文化局': True,
#    '文學': True,
#    '文學獎': True,
#    '新聞': True,
#    '新聞稿': True,
#    '日前': True,
#    '書籍': True,
#    '會議': True,
#    '林': True,
#    '林瑞明': True,
#    '正': True,
#    '歲': True,
#    '歷史': True,
#    '獎項': True,
#    '發布': True,
#    '相關': True,
#    '研究': True,
#    '評審': True,
#    '評論': True,
#    '詩人': True,
#    '貢獻': True,
#    '身分': True,
#    '辦理': True,
#    '辭世': True,
#    '重要': True,
#    '館長': True},
#   '文化'),
#  ({'一些': True,
#    '一部': True,
#    '上揚': True,
#    '上漲': True,
#    '中國': True,
#    '主席': True,
#    '主管': True,
#    '主要': True,
#    '亞洲': True,
#    '令': True,
#    '休兵': True,
#    '優於': True,
#    '全球': True,
#    '公司': True,
#    '共和黨': True,
#    '出口': True,
#    '出席': True,
#    '加徵': True,
#    '勁揚': True,
#    '協議': True,
#    '同意': True,
#    '國家': True,
#    '報告': True,
#    '大漲': True,
#    '大豆': True,
#    '客戶': True,
#    '峰會': True,
#    '川普': True,
#    '已': True,
#    '市場': True,
#    '帶動': True,
#    '引發': True,
#    '恆生': True,
#    '投資': True,
#    '投資人': True,
#    '持續': True,
#    '指數': True,
#    '提醒': True,
#    '新': True,
#    '新加坡': True,
#    '日本': True,
#    '日經': True,
#    '時間': True,
#    '暫停': True,
#    '會談': True,
#    '東京': True,
#    '樂觀': True,
#    '機會': True,
#    '滬深': True,
#    '漲': True,
#    '澳洲': True,
#    '無': True,
#    '獲勝': True,
#    '現在': True,
#    '目前': True,
#    '知道': True,
#    '短期': True,
#    '研究': True,
#    '確定': True,
#    '磋商': True,
#    '紛紛': True,
#    '經濟': True,
#    '綜合': True,
#    '網路': True,
#    '總統': True,
#    '美': True,
#    '美中': True,
#    '美國': True,
#    '習近平': True,
#    '股': True,
#    '股市': True,
#    '至少': True,
#    '落幕': True,
#    '衝突': True,
#    '解決': True,
#    '證券': True,
#    '貿易': True,
#    '貿易戰': True,
#    '走高': True,
#    '超過': True,
#    '造成': True,
#    '進展': True,
#    '進行': True,
#    '逾': True,
#    '部門': True,
#    '重要': True,
#    '金融': True,
#    '銀行': True,
#    '開心': True,
#    '開盤': True,
#    '關稅': True,
#    '阿根廷': True,
#    '降低': True,
#    '集團': True,
#    '雙方': True,
#    '預期': True,
#    '風險': True,
#    '香港': True,
#    '駐': True},
#   '證券'),
#  ({'位於': True,
#    '公園': True,
#    '台東': True,
#    '名': True,
#    '名為': True,
#    '名稱': True,
#    '呈現': True,
#    '國家': True,
#    '地方': True,
#    '地質': True,
#    '多元': True,
#    '大學': True,
#    '完成': True,
#    '小': True,
#    '希望': True,
#    '引起': True,
#    '接受': True,
#    '族群': True,
#    '最近': True,
#    '有意': True,
#    '正': True,
#    '歷史': True,
#    '民眾': True,
#    '準備': True,
#    '特色': True,
#    '目前': True,
#    '相較': True,
#    '確定': True,
#    '社區': True,
#    '稱': True,
#    '管理': True,
#    '結合': True,
#    '觀光': True,
#    '觀光局': True,
#    '評估': True,
#    '長': True,
#    '關切': True},
#   '地方'),
#  ({'I': True,
#    'LED': True,
#    'VR': True,
#    '下滑': True,
#    '主因': True,
#    '供應鏈': True,
#    '傳統': True,
#    '億': True,
#    '元': True,
#    '公布': True,
#    '出貨': True,
#    '包含': True,
#    '去年': True,
#    '合併': True,
#    '同期': True,
#    '呈現': True,
#    '季': True,
#    '客戶': True,
#    '實境': True,
#    '專業': True,
#    '導入': True,
#    '小': True,
#    '已': True,
#    '年減': True,
#    '廠': True,
#    '德國': True,
#    '感測': True,
#    '應用': True,
#    '戶外': True,
#    '手機': True,
#    '技術': True,
#    '擴增': True,
#    '整合': True,
#    '新': True,
#    '新台幣': True,
#    '月減': True,
#    '模組': True,
#    '歐洲': True,
#    '正式': True,
#    '深度': True,
#    '減少': True,
#    '營收': True,
#    '獲得': True,
#    '產品': True,
#    '目前': True,
#    '累計': True,
#    '結束': True,
#    '致': True,
#    '虛擬': True,
#    '辨識': True,
#    '達': True,
#    '開發': True,
#    '電子': True,
#    '順利': True,
#    '顯示': True,
#    '首度': True},
#   '證券'),
#  ({'一場': True,
#    '主辦': True,
#    '主題': True,
#    '介紹': True,
#    '代理': True,
#    '令': True,
#    '位': True,
#    '作品': True,
#    '來自': True,
#    '值得': True,
#    '具': True,
#    '前往': True,
#    '創作': True,
#    '創造': True,
#    '反轉': True,
#    '呈現': True,
#    '喜歡': True,
#    '單位': True,
#    '國內': True,
#    '國際': True,
#    '城市': True,
#    '多元': True,
#    '大型': True,
#    '屆': True,
#    '展出': True,
#    '展現': True,
#    '感受': True,
#    '成長': True,
#    '挑戰': True,
#    '文化': True,
#    '文化局': True,
#    '方向': True,
#    '日本': True,
#    '期間': True,
#    '欣賞': True,
#    '民眾': True,
#    '活動': True,
#    '火力': True,
#    '特別': True,
#    '現場': True,
#    '產業': True,
#    '登場': True,
#    '精彩': True,
#    '組': True,
#    '結合': True,
#    '荷蘭': True,
#    '藝術': True,
#    '藝術家': True,
#    '藝術節': True,
#    '處': True,
#    '辛苦': True,
#    '運用': True,
#    '過程': True,
#    '類': True,
#    '首度': True,
#    '高雄': True,
#    '高雄市': True},
#   '文化'),
#  ({'中華': True,
#    '之間': True,
#    '交流': True,
#    '今晚': True,
#    '代表': True,
#    '作品': True,
#    '內容': True,
#    '兩國': True,
#    '共同': True,
#    '典禮': True,
#    '創作': True,
#    '劉': True,
#    '協會': True,
#    '去年': True,
#    '參與': True,
#    '台': True,
#    '合作': True,
#    '名': True,
#    '外': True,
#    '天': True,
#    '屆': True,
#    '展覽': True,
#    '年來': True,
#    '廖': True,
#    '強調': True,
#    '意見': True,
#    '批': True,
#    '指出': True,
#    '故宮': True,
#    '教育': True,
#    '教育部': True,
#    '文化': True,
#    '新': True,
#    '新加坡': True,
#    '旅客': True,
#    '旅遊': True,
#    '暨': True,
#    '更多': True,
#    '曾': True,
#    '會員': True,
#    '次長': True,
#    '為例': True,
#    '理念': True,
#    '當代': True,
#    '美術': True,
#    '致詞': True,
#    '舉辦': True,
#    '萬': True,
#    '藝文': True,
#    '藝術': True,
#    '藝術家': True,
#    '處': True,
#    '訪問': True,
#    '認為': True,
#    '說明': True,
#    '赴': True,
#    '超過': True,
#    '開幕': True,
#    '項': True,
#    '首': True,
#    '駐': True,
#    '高中': True},
#   '文化'),
#  ({'中午': True,
#    '刀傷': True,
#    '分局': True,
#    '到場': True,
#    '協助': True,
#    '卻': True,
#    '受傷': True,
#    '員警': True,
#    '地方': True,
#    '報案': True,
#    '場': True,
#    '壓制': True,
#    '奪下': True,
#    '女子': True,
#    '就醫': True,
#    '左右': True,
#    '已': True,
#    '彰化': True,
#    '急救': True,
#    '想要': True,
#    '拒絕': True,
#    '指出': True,
#    '指揮': True,
#    '接獲': True,
#    '昨天': True,
#    '最後': True,
#    '檢察官': True,
#    '民眾': True,
#    '治療': True,
#    '準備': True,
#    '無': True,
#    '獲報': True,
#    '現場': True,
#    '疑似': True,
#    '立即': True,
#    '美': True,
#    '蔡姓': True,
#    '處': True,
#    '處理': True,
#    '警察': True,
#    '警察局': True,
#    '送往': True,
#    '送醫': True,
#    '醫院': True,
#    '需': True,
#    '需要': True},
#   '社會'),
#  ({'AI': True,
#    '世界': True,
#    '中心': True,
#    '串聯': True,
#    '主題': True,
#    '交流': True,
#    '人工': True,
#    '人才': True,
#    '人類': True,
#    '件': True,
#    '使': True,
#    '使用': True,
#    '儀式': True,
#    '公司': True,
#    '分': True,
#    '創作': True,
#    '創新': True,
#    '創造': True,
#    '協助': True,
#    '合作': True,
#    '吸引': True,
#    '咖啡': True,
#    '啟動': True,
#    '單位': True,
#    '國際': True,
#    '園區': True,
#    '團隊': True,
#    '培育': True,
#    '基地': True,
#    '基礎': True,
#    '大賽': True,
#    '家': True,
#    '實際': True,
#    '就業': True,
#    '展出': True,
#    '展示': True,
#    '工作': True,
#    '市場': True,
#    '帶動': True,
#    '平台': True,
#    '應用': True,
#    '成果': True,
#    '成立': True,
#    '技術': True,
#    '投資': True,
#    '指出': True,
#    '推廣': True,
#    '提供': True,
#    '擴大': True,
#    '新創': True,
#    '智慧': True,
#    '更多': True,
#    '期待': True,
#    '案': True,
#    '機器': True,
#    '機器人': True,
#    '機會': True,
#    '機械': True,
#    '機構': True,
#    '次長': True,
#    '民眾': True,
#    '活動': True,
#    '現場': True,
#    '產品': True,
#    '產業': True,
#    '產生': True,
#    '發展': True,
#    '相關': True,
#    '研究': True,
#    '科技': True,
#    '科技部': True,
#    '種': True,
#    '空間': True,
#    '管理': True,
#    '聯合': True,
#    '自動化': True,
#    '舉辦': True,
#    '衛星': True,
#    '製作': True,
#    '計畫': True,
#    '設備': True,
#    '透過': True,
#    '進駐': True,
#    '逾': True,
#    '部': True,
#    '開發': True,
#    '關鍵': True,
#    '領域': True,
#    '類': True,
#    '體驗': True},
#   '產經'),
#  ({'中心': True,
#    '事業': True,
#    '依據': True,
#    '傳播': True,
#    '億美': True,
#    '元': True,
#    '先進': True,
#    '全球': True,
#    '公司': True,
#    '分析': True,
#    '半導體': True,
#    '因應': True,
#    '國際': True,
#    '太': True,
#    '奈米': True,
#    '完成': True,
#    '宣布': True,
#    '展出': True,
#    '展示': True,
#    '展覽': True,
#    '工具': True,
#    '市場': True,
#    '廠': True,
#    '應用': True,
#    '手機': True,
#    '技術': True,
#    '指出': True,
#    '推出': True,
#    '數據': True,
#    '新興': True,
#    '方案': True,
#    '旗下': True,
#    '日前': True,
#    '日本': True,
#    '晶片': True,
#    '智慧': True,
#    '智慧型': True,
#    '東京': True,
#    '業績': True,
#    '汽車': True,
#    '深耕': True,
#    '測試': True,
#    '無線': True,
#    '獎金': True,
#    '登場': True,
#    '發展': True,
#    '系統': True,
#    '網路': True,
#    '美元': True,
#    '舉辦': True,
#    '萬': True,
#    '行動': True,
#    '行銷': True,
#    '表現': True,
#    '製造': True,
#    '解決': True,
#    '記憶': True,
#    '記憶體': True,
#    '設備': True,
#    '設施': True,
#    '設計': True,
#    '購買': True,
#    '近年': True,
#    '近日': True,
#    '通訊': True,
#    '連結': True,
#    '進行': True,
#    '醫療': True,
#    '針對': True,
#    '開發': True,
#    '電子': True,
#    '需求': True,
#    '預計': True,
#    '高達': True},
#   '產經'),
#  ({'F': True,
#    '中國': True,
#    '保障': True,
#    '內容': True,
#    '內閣': True,
#    '功能': True,
#    '加強': True,
#    '包括': True,
#    '化': True,
#    '只': True,
#    '召開': True,
#    '國防': True,
#    '報導': True,
#    '大型': True,
#    '大綱': True,
#    '太空': True,
#    '學者': True,
#    '安全': True,
#    '完成': True,
#    '專家': True,
#    '已': True,
#    '必要': True,
#    '情報': True,
#    '持續': True,
#    '提出': True,
#    '擁有': True,
#    '改善': True,
#    '政府': True,
#    '新': True,
#    '新聞': True,
#    '日本': True,
#    '會議': True,
#    '機場': True,
#    '正': True,
#    '正在': True,
#    '比較': True,
#    '決定': True,
#    '無': True,
#    '相較': True,
#    '真正': True,
#    '短': True,
#    '研議': True,
#    '約': True,
#    '考慮': True,
#    '航空': True,
#    '艘': True,
#    '草案': True,
#    '計畫': True,
#    '討論': True,
#    '認為': True,
#    '距離': True,
#    '軍事': True,
#    '運用': True,
#    '開發': True,
#    '防衛': True,
#    '降落': True,
#    '飛彈': True,
#    '飛行': True},
#   '國際'),
#  ({'一致': True,
#    '上映': True,
#    '主角': True,
#    '之前': True,
#    '亞洲': True,
#    '交流': True,
#    '全台': True,
#    '出席': True,
#    '劇本': True,
#    '協商': True,
#    '原創': True,
#    '台': True,
#    '喜愛': True,
#    '執導': True,
#    '場': True,
#    '女': True,
#    '完全': True,
#    '宣告': True,
#    '導演': True,
#    '已': True,
#    '已經': True,
#    '影展': True,
#    '徐譽庭': True,
#    '得到': True,
#    '想要': True,
#    '意外': True,
#    '愛上': True,
#    '拿下': True,
#    '放映': True,
#    '新': True,
#    '新台幣': True,
#    '日本': True,
#    '昨晚': True,
#    '時間': True,
#    '最佳': True,
#    '李': True,
#    '歌曲': True,
#    '正': True,
#    '法國': True,
#    '演出': True,
#    '演員': True,
#    '獎': True,
#    '看到': True,
#    '真的': True,
#    '知道': True,
#    '票房': True,
#    '立即': True,
#    '萬元': True,
#    '觀眾': True,
#    '評審': True,
#    '認為': True,
#    '謝盈萱': True,
#    '資深': True,
#    '身分': True,
#    '身為': True,
#    '邱澤': True,
#    '部': True,
#    '金馬': True,
#    '金馬獎': True,
#    '開心': True,
#    '開賣': True,
#    '電影': True,
#    '電影節': True,
#    '香港': True},
#   '娛樂'),
#  ({'一定': True,
#    '上任': True,
#    '不斷': True,
#    '串聯': True,
#    '主要': True,
#    '些': True,
#    '作業': True,
#    '使用': True,
#    '保持': True,
#    '保障': True,
#    '億': True,
#    '優先': True,
#    '優勢': True,
#    '元': True,
#    '全': True,
#    '出貨': True,
#    '出貨量': True,
#    '分鐘': True,
#    '前瞻': True,
#    '區域': True,
#    '參加': True,
#    '受惠': True,
#    '台': True,
#    '台中': True,
#    '台南': True,
#    '啟動': True,
#    '國內': True,
#    '園區': True,
#    '地區': True,
#    '基礎': True,
#    '大都會': True,
#    '太': True,
#    '客戶': True,
#    '家': True,
#    '工作': True,
#    '工程': True,
#    '市區': True,
#    '市場': True,
#    '市長': True,
#    '度': True,
#    '座': True,
#    '廠': True,
#    '建材': True,
#    '建設': True,
#    '強大': True,
#    '成立': True,
#    '投資': True,
#    '抵達': True,
#    '指出': True,
#    '捷運': True,
#    '推動': True,
#    '提供': True,
#    '擴大': True,
#    '政府': True,
#    '政策': True,
#    '新': True,
#    '新台幣': True,
#    '服務': True,
#    '未來': True,
#    '材料': True,
#    '水': True,
#    '法規': True,
#    '準備': True,
#    '火車': True,
#    '瑜': True,
#    '當選': True,
#    '當選人': True,
#    '發展': True,
#    '目前': True,
#    '看好': True,
#    '研發': True,
#    '科學': True,
#    '科技': True,
#    '管理': True,
#    '經濟': True,
#    '總計': True,
#    '興建': True,
#    '萬': True,
#    '規定': True,
#    '計畫': True,
#    '認為': True,
#    '進行': True,
#    '逾': True,
#    '重大': True,
#    '鐵路': True,
#    '韓國': True,
#    '順利': True,
#    '預估': True,
#    '高雄': True},
#   '產經'),
#  ({'一直': True,
#    '中國': True,
#    '事務': True,
#    '些': True,
#    '人權': True,
#    '令': True,
#    '保護': True,
#    '分子': True,
#    '召開': True,
#    '地區': True,
#    '報導': True,
#    '安全': True,
#    '宗教': True,
#    '尋求': True,
#    '已': True,
#    '影響': True,
#    '必要': True,
#    '打擊': True,
#    '批評': True,
#    '措施': True,
#    '教育': True,
#    '文化': True,
#    '新疆': True,
#    '是否': True,
#    '暴力': True,
#    '查證': True,
#    '民族': True,
#    '聯合': True,
#    '聯合國': True,
#    '行動': True,
#    '要求': True,
#    '記者會': True,
#    '辦公室': True,
#    '進入': True},
#   '國際'),
#  ({'些': True,
#    '人員': True,
#    '份': True,
#    '公園': True,
#    '受到': True,
#    '國家': True,
#    '國際': True,
#    '團隊': True,
#    '基因': True,
#    '報告': True,
#    '島': True,
#    '工作': True,
#    '已': True,
#    '已經': True,
#    '強化': True,
#    '影響': True,
#    '恢復': True,
#    '感染': True,
#    '提供': True,
#    '擁有': True,
#    '數量': True,
#    '斯': True,
#    '更多': True,
#    '最後': True,
#    '歲': True,
#    '死亡': True,
#    '癌症': True,
#    '發展': True,
#    '發現': True,
#    '發表': True,
#    '目前': True,
#    '相較': True,
#    '相關': True,
#    '研究': True,
#    '科學': True,
#    '科學家': True,
#    '種': True,
#    '系統': True,
#    '組': True,
#    '自然': True,
#    '處': True,
#    '象龜': True,
#    '超過': True},
#   '科技'),
#  ({'下午': True,
#    '主管': True,
#    '了解': True,
#    '事': True,
#    '人事': True,
#    '依據': True,
#    '保障': True,
#    '做': True,
#    '億': True,
#    '元': True,
#    '先前': True,
#    '公投': True,
#    '協調': True,
#    '占': True,
#    '受': True,
#    '司法': True,
#    '名': True,
#    '員工': True,
#    '困難': True,
#    '委員': True,
#    '希望': True,
#    '引發': True,
#    '影響': True,
#    '思考': True,
#    '感覺': True,
#    '憲法': True,
#    '指出': True,
#    '提到': True,
#    '提案': True,
#    '新台幣': True,
#    '是否': True,
#    '普遍': True,
#    '最後': True,
#    '會議': True,
#    '有點': True,
#    '案': True,
#    '條': True,
#    '法官': True,
#    '法律': True,
#    '法院': True,
#    '溝通': True,
#    '爭議': True,
#    '獨立': True,
#    '監察院': True,
#    '秘書': True,
#    '秘書長': True,
#    '範圍': True,
#    '緊張': True,
#    '總統': True,
#    '與會': True,
#    '英文': True,
#    '蔡英文': True,
#    '行政': True,
#    '行政院': True,
#    '要求': True,
#    '規定': True,
#    '解決': True,
#    '討論': True,
#    '認為': True,
#    '調查': True,
#    '質疑': True,
#    '過去': True,
#    '遭': True,
#    '關係': True,
#    '預算': True},
#   '政治')]

# %%
size = int(len(featuresets)*0.7)
train_set, test_set = featuresets[:size], featuresets[size:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.75

# %%
test_news="""
資深媒體人劉寶傑確定向主持11年的《關鍵時刻》請辭，將在明年1月永久交出主持棒，他超生動的主持方式，樹立獨特個人風格，深獲不少觀眾喜愛，因此告別《關鍵》後的下一步一直備受矚目，有消息傳出，劉寶傑之後將轉戰年代，取代跟《關鍵》同時段的《新聞追追追》。

檢視相片
▲劉寶傑下一步動向備受矚目。（圖／翻攝自臉書）

年代《新聞追追追》由主播安幼琪與張啟楷搭檔主持7年，不過《自由時報》報導，劉寶傑可能到年代，《追追追》恐怕面臨收攤危機，但年代內部知情人士指出，電視台的老闆政治立場和劉寶傑不同，挖角的機率應該不大，認為節目不會收攤，但可能會轉型或改節目名稱，主持人或許也會有變動。

檢視相片
▲《新聞追追追》恐收攤？（圖／翻攝自YouTube）

對此，安幼琪透露上周公司內部確實有開會，但只是針對節目來賓的選擇做小調整，希望能夠多聽年輕人的聲音，也表示跟搭檔張啟楷合作得很愉快，而張啟楷則回應沒有聽過類似的消息。

"""
f = pos_features(test_news,300)
print(f)
print(classifier.classify(f))
# Out:
# {'年代': True, '關鍵': True, '新聞': True, '節目': True, '消息': True, '楷': True, '內部': True, '資深': True, '媒體': True, '確定': True, '請辭': True, '明年': True, '方式': True, '風格': True, '觀眾': True, '喜愛': True, '一直': True, '之後': True, '段': True, '臉書': True, '自由': True, '自由時報': True, '報導': True, '面臨': True, '危機': True, '人士': True, '指出': True, '電視': True, '電視台': True, '老闆': True, '政治': True, '立場': True, '應該': True, '認為': True, '轉型': True, '名稱': True, '恐': True, 'YouTube': True, '透露': True, '公司': True, '針對': True, '選擇': True, '做': True, '小': True, '調整': True, '希望': True, '能夠': True, '年輕': True, '聲音': True, '合作': True, '回應': True}
# 娛樂
